# %% [markdown]
# # PLAsTiCC time series classification
# This is a ML code that performs classification of the time series from the Photometric LSST Astronomical Time-Series Classification Challenge (PLAsTiCC; https://www.kaggle.com/c/PLAsTiCC-2018). A sample representation of the data is provided after loading the data.
#
# Labels are provided for the training set.
#
# The steps are the following: <br>
# 1. Import libraries and sample
# 2. Split sub-samples (training, validation, testing)
# 3. Fit with various classifier and check performance
# 4. Compare various classifiers in testing sample
#
# The alternative classifiers provide first guesses on the expected accuracy
#
# ## 2.2.2 : this model takes into account only the extra-Galactic classes (# 15, 42, 52, 62, 64, 67, 88, 90, 95) for which the redshift is not 0
#
# (based on v2.1)

# %% [markdown]
# ## Loading Data

# %%
# Importing Libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn import datasets, utils, metrics
from sklearn.svm import LinearSVC
from sklearn.svm import NuSVC
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.simplefilter('ignore')

# %%
path_to_data = "training_data_v1/"

# %%
import glob
files = sorted(glob.glob(path_to_data + "/*.npy"))

import progressbar


#restore:
n_files = len(files)
#debug:n_files = 1000


# > Loading series / labels:
# <indexed as ID array>
    
IDs   = []
# ID number (without "id-")
bands = []
# band name (without "band-") [0 .. 5]

series = []
labels = []

Duration_MJDs = []
# array of duration of light curves


from sklearn.preprocessing import StandardScaler 
ss = StandardScaler()

bar = progressbar.ProgressBar(maxval=n_files, widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()
for i in range(n_files):

    bar.update(i+1)

    # data standardization
    tmp = np.load(files[i])
#    tmp1 = np.load(files[i])
#    tmp = ss.fit_transform(tmp1)  
    
#    print(files[i])
    """
    if '90' in files[i] and class_90_index<150:
        print("include that",class_90_index,"/150") 
        class_90_index += 1
        pass
    elif '90' in files[i] and class_90_index>=150:
        print("EXCLUDING !",class_90_index,"/150")
        class_90_index += 1
        continue
    """
    
    # taking into account the extra-Galactic classes only (ie z!=0)
#    if ('class-6.npy' in files[i]) or ( 'class-16.npy' in files[i] ) or ('class-53.npy' in files[i]) or ('class-65.npy' in files[i]) or ('class-92.npy' in files[i]):
    if ('class-15.npy' in files[i]) or ( 'class-42.npy' in files[i] ) or ('class-52.npy' in files[i]) or ('class-62.npy' in files[i]) or ('class-64.npy' in files[i]) or ('class-67.npy' in files[i]) or ('class-88.npy' in files[i]) or ('class-90.npy' in files[i]) or ('class-95.npy' in files[i]):
        print('keeping...', files[i])
        pass
    else:
        print('rejecting...')
        continue

    IDs.append(files[i].split("/")[-1].split("_")[0].strip("id-"))
    bands.append(int(files[i].split("/")[-1].split("_")[1].strip("band-")))

    band = int(bands[-1])
    # current band index [0 .. 6]
    
    series.append(tmp)
    labels.append(files[i].split("/")[-1].split("-")[-1].strip(".npy"))

    
    # > Loading single data files:
    #
    # Data format:
    #
    # Modified Juilian Date, Flux, err_Flux, Detected (flag)

    MJD = series[-1][:,0]
    # Modified Julian Date
       
    F = series[-1][:,1]
    # flux
        
    F_err = series[-1][:,2]
    # flux error
    
    
    Duration_MJDs.append(MJD[-1] - MJD[0])

bar.finish()
# Out:
# [                                                                        ]   1%
# keeping... training_data_v1/id-100012747_band-0_class-62.npy
# keeping... training_data_v1/id-100012747_band-1_class-62.npy
# keeping... training_data_v1/id-100012747_band-2_class-62.npy
# keeping... training_data_v1/id-100012747_band-3_class-62.npy
# keeping... training_data_v1/id-100012747_band-4_class-62.npy
# keeping... training_data_v1/id-100012747_band-5_class-62.npy
# keeping... training_data_v1/id-100017743_band-0_class-42.npy
# keeping... training_data_v1/id-100017743_band-1_class-42.npy
# keeping... training_data_v1/id-100017743_band-2_class-42.npy
# keeping... training_data_v1/id-100017743_band-3_class-42.npy
# keeping... training_data_v1/id-100017743_band-4_class-42.npy
# keeping... training_data_v1/id-100017743_band-5_class-42.npy
# keeping... training_data_v1/id-100018744_band-0_class-90.npy
# keeping... training_data_v1/id-100018744_band-1_class-90.npy
# keeping... training_data_v1/id-100018744_band-2_class-90.npy
# keeping... training_data_v1/id-100018744_band-3_class-90.npy
# keeping... training_data_v1/id-100018744_band-4_class-90.npy
# keeping... training_data_v1/id-100018744_band-5_class-90.npy
# keeping... training_data_v1/id-100045757_band-0_class-88.npy
# keeping... training_data_v1/id-100045757_band-1_class-88.npy
# keeping... training_data_v1/id-100045757_band-2_class-88.npy
# keeping... training_data_v1/id-100045757_band-3_class-88.npy
# keeping... training_data_v1/id-100045757_band-4_class-88.npy
# keeping... training_data_v1/id-100045757_band-5_class-88.npy
# keeping... training_data_v1/id-100057_band-0_class-90.npy
# keeping... training_data_v1/id-100057_band-1_class-90.npy
# keeping... training_data_v1/id-100057_band-2_class-90.npy
# keeping... training_data_v1/id-100057_band-3_class-90.npy
# keeping... training_data_v1/id-100057_band-4_class-90.npy
# keeping... training_data_v1/id-100057_band-5_class-90.npy
# keeping... training_data_v1/id-100097_band-0_class-42.npy
# keeping... training_data_v1/id-100097_band-1_class-42.npy
# keeping... training_data_v1/id-100097_band-2_class-42.npy
# keeping... training_data_v1/id-100097_band-3_class-42.npy
# keeping... training_data_v1/id-100097_band-4_class-42.npy
# keeping... training_data_v1/id-100097_band-5_class-42.npy
# keeping... training_data_v1/id-100101119_band-0_class-90.npy
# keeping... training_data_v1/id-100101119_band-1_class-90.npy
# keeping... training_data_v1/id-100101119_band-2_class-90.npy
# keeping... training_data_v1/id-100101119_band-3_class-90.npy
# keeping... training_data_v1/id-100101119_band-4_class-90.npy
# keeping... training_data_v1/id-100101119_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-100133_band-0_class-42.npy
# keeping... training_data_v1/id-100133_band-1_class-42.npy
# keeping... training_data_v1/id-100133_band-2_class-42.npy
# keeping... training_data_v1/id-100133_band-3_class-42.npy
# keeping... training_data_v1/id-100133_band-4_class-42.npy
# keeping... training_data_v1/id-100133_band-5_class-42.npy
# keeping... training_data_v1/id-100145299_band-0_class-90.npy
# keeping... training_data_v1/id-100145299_band-1_class-90.npy
# keeping... training_data_v1/id-100145299_band-2_class-90.npy
# keeping... training_data_v1/id-100145299_band-3_class-90.npy
# keeping... training_data_v1/id-100145299_band-4_class-90.npy
# keeping... training_data_v1/id-100145299_band-5_class-90.npy
# keeping... training_data_v1/id-100164081_band-0_class-95.npy
# keeping... training_data_v1/id-100164081_band-1_class-95.npy
# keeping... training_data_v1/id-100164081_band-2_class-95.npy
# keeping... training_data_v1/id-100164081_band-3_class-95.npy
# keeping... training_data_v1/id-100164081_band-4_class-95.npy
# keeping... training_data_v1/id-100164081_band-5_class-95.npy
# keeping... training_data_v1/id-100185188_band-0_class-88.npy
# keeping... training_data_v1/id-100185188_band-1_class-88.npy
# keeping... training_data_v1/id-100185188_band-2_class-88.npy
# keeping... training_data_v1/id-100185188_band-3_class-88.npy
# keeping... training_data_v1/id-100185188_band-4_class-88.npy
# keeping... training_data_v1/id-100185188_band-5_class-88.npy
# keeping... training_data_v1/id-100229335_band-0_class-88.npy
# keeping... training_data_v1/id-100229335_band-1_class-88.npy
# keeping... training_data_v1/id-100229335_band-2_class-88.npy
# keeping... training_data_v1/id-100229335_band-3_class-88.npy
# keeping... training_data_v1/id-100229335_band-4_class-88.npy
# keeping... training_data_v1/id-100229335_band-5_class-88.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-100331_band-0_class-42.npy
# keeping... training_data_v1/id-100331_band-1_class-42.npy
# keeping... training_data_v1/id-100331_band-2_class-42.npy
# keeping... training_data_v1/id-100331_band-3_class-42.npy
# keeping... training_data_v1/id-100331_band-4_class-42.npy
# keeping... training_data_v1/id-100331_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-100426880_band-0_class-42.npy
# keeping... training_data_v1/id-100426880_band-1_class-42.npy
# keeping... training_data_v1/id-100426880_band-2_class-42.npy
# keeping... training_data_v1/id-100426880_band-3_class-42.npy
# keeping... training_data_v1/id-100426880_band-4_class-42.npy
# keeping... training_data_v1/id-100426880_band-5_class-42.npy
# keeping... training_data_v1/id-100431044_band-0_class-95.npy
# keeping... training_data_v1/id-100431044_band-1_class-95.npy
# keeping... training_data_v1/id-100431044_band-2_class-95.npy
# keeping... training_data_v1/id-100431044_band-3_class-95.npy
# keeping... training_data_v1/id-100431044_band-4_class-95.npy
# keeping... training_data_v1/id-100431044_band-5_class-95.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-100560232_band-0_class-90.npy
# keeping... training_data_v1/id-100560232_band-1_class-90.npy
# keeping... training_data_v1/id-100560232_band-2_class-90.npy
# keeping... training_data_v1/id-100560232_band-3_class-90.npy
# keeping... training_data_v1/id-100560232_band-4_class-90.npy
# keeping... training_data_v1/id-100560232_band-5_class-90.npy
# keeping... training_data_v1/id-100571928_band-0_class-90.npy
# keeping... training_data_v1/id-100571928_band-1_class-90.npy
# keeping... training_data_v1/id-100571928_band-2_class-90.npy
# keeping... training_data_v1/id-100571928_band-3_class-90.npy
# keeping... training_data_v1/id-100571928_band-4_class-90.npy
# keeping... training_data_v1/id-100571928_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-100588254_band-0_class-42.npy
# keeping... training_data_v1/id-100588254_band-1_class-42.npy
# keeping... training_data_v1/id-100588254_band-2_class-42.npy
# keeping... training_data_v1/id-100588254_band-3_class-42.npy
# keeping... training_data_v1/id-100588254_band-4_class-42.npy
# keeping... training_data_v1/id-100588254_band-5_class-42.npy
# keeping... training_data_v1/id-100590632_band-0_class-90.npy
# keeping... training_data_v1/id-100590632_band-1_class-90.npy
# keeping... training_data_v1/id-100590632_band-2_class-90.npy
# keeping... training_data_v1/id-100590632_band-3_class-90.npy
# keeping... training_data_v1/id-100590632_band-4_class-90.npy
# keeping... training_data_v1/id-100590632_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-100639351_band-0_class-15.npy
# keeping... training_data_v1/id-100639351_band-1_class-15.npy
# keeping... training_data_v1/id-100639351_band-2_class-15.npy
# keeping... training_data_v1/id-100639351_band-3_class-15.npy
# keeping... training_data_v1/id-100639351_band-4_class-15.npy
# keeping... training_data_v1/id-100639351_band-5_class-15.npy
# keeping... training_data_v1/id-100653729_band-0_class-90.npy
# keeping... training_data_v1/id-100653729_band-1_class-90.npy
# keeping... training_data_v1/id-100653729_band-2_class-90.npy
# keeping... training_data_v1/id-100653729_band-3_class-90.npy
# keeping... training_data_v1/id-100653729_band-4_class-90.npy
# keeping... training_data_v1/id-100653729_band-5_class-90.npy
# keeping... training_data_v1/id-10068587_band-0_class-90.npy
# keeping... training_data_v1/id-10068587_band-1_class-90.npy
# keeping... training_data_v1/id-10068587_band-2_class-90.npy
# keeping... training_data_v1/id-10068587_band-3_class-90.npy
# keeping... training_data_v1/id-10068587_band-4_class-90.npy
# keeping... training_data_v1/id-10068587_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-100789268_band-0_class-42.npy
# keeping... training_data_v1/id-100789268_band-1_class-42.npy
# keeping... training_data_v1/id-100789268_band-2_class-42.npy
# keeping... training_data_v1/id-100789268_band-3_class-42.npy
# keeping... training_data_v1/id-100789268_band-4_class-42.npy
# keeping... training_data_v1/id-100789268_band-5_class-42.npy
# keeping... training_data_v1/id-100826219_band-0_class-15.npy
# keeping... training_data_v1/id-100826219_band-1_class-15.npy
# keeping... training_data_v1/id-100826219_band-2_class-15.npy
# keeping... training_data_v1/id-100826219_band-3_class-15.npy
# keeping... training_data_v1/id-100826219_band-4_class-15.npy
# keeping... training_data_v1/id-100826219_band-5_class-15.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-100874766_band-0_class-62.npy
# keeping... training_data_v1/id-100874766_band-1_class-62.npy
# keeping... training_data_v1/id-100874766_band-2_class-62.npy
# keeping... training_data_v1/id-100874766_band-3_class-62.npy
# keeping... training_data_v1/id-100874766_band-4_class-62.npy
# keeping... training_data_v1/id-100874766_band-5_class-62.npy
# keeping... training_data_v1/id-100890774_band-0_class-42.npy
# keeping... training_data_v1/id-100890774_band-1_class-42.npy
# keeping... training_data_v1/id-100890774_band-2_class-42.npy
# keeping... training_data_v1/id-100890774_band-3_class-42.npy
# keeping... training_data_v1/id-100890774_band-4_class-42.npy
# keeping... training_data_v1/id-100890774_band-5_class-42.npy
# keeping... training_data_v1/id-100928881_band-0_class-90.npy
# keeping... training_data_v1/id-100928881_band-1_class-90.npy
# keeping... training_data_v1/id-100928881_band-2_class-90.npy
# keeping... training_data_v1/id-100928881_band-3_class-90.npy
# keeping... training_data_v1/id-100928881_band-4_class-90.npy
# keeping... training_data_v1/id-100928881_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101023493_band-0_class-90.npy
# keeping... training_data_v1/id-101023493_band-1_class-90.npy
# keeping... training_data_v1/id-101023493_band-2_class-90.npy
# keeping... training_data_v1/id-101023493_band-3_class-90.npy
# keeping... training_data_v1/id-101023493_band-4_class-90.npy
# keeping... training_data_v1/id-101023493_band-5_class-90.npy
# keeping... training_data_v1/id-101050_band-0_class-90.npy
# keeping... training_data_v1/id-101050_band-1_class-90.npy
# keeping... training_data_v1/id-101050_band-2_class-90.npy
# keeping... training_data_v1/id-101050_band-3_class-90.npy
# keeping... training_data_v1/id-101050_band-4_class-90.npy
# keeping... training_data_v1/id-101050_band-5_class-90.npy
# keeping... training_data_v1/id-101074183_band-0_class-15.npy
# keeping... training_data_v1/id-101074183_band-1_class-15.npy
# keeping... training_data_v1/id-101074183_band-2_class-15.npy
# keeping... training_data_v1/id-101074183_band-3_class-15.npy
# keeping... training_data_v1/id-101074183_band-4_class-15.npy
# keeping... training_data_v1/id-101074183_band-5_class-15.npy
# keeping... training_data_v1/id-101119111_band-0_class-90.npy
# keeping... training_data_v1/id-101119111_band-1_class-90.npy
# keeping... training_data_v1/id-101119111_band-2_class-90.npy
# keeping... training_data_v1/id-101119111_band-3_class-90.npy
# keeping... training_data_v1/id-101119111_band-4_class-90.npy
# keeping... training_data_v1/id-101119111_band-5_class-90.npy
# keeping... training_data_v1/id-101125840_band-0_class-42.npy
# keeping... training_data_v1/id-101125840_band-1_class-42.npy
# keeping... training_data_v1/id-101125840_band-2_class-42.npy
# keeping... training_data_v1/id-101125840_band-3_class-42.npy
# keeping... training_data_v1/id-101125840_band-4_class-42.npy
# keeping... training_data_v1/id-101125840_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-10115621_band-0_class-90.npy
# keeping... training_data_v1/id-10115621_band-1_class-90.npy
# keeping... training_data_v1/id-10115621_band-2_class-90.npy
# keeping... training_data_v1/id-10115621_band-3_class-90.npy
# keeping... training_data_v1/id-10115621_band-4_class-90.npy
# keeping... training_data_v1/id-10115621_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101241553_band-0_class-42.npy
# keeping... training_data_v1/id-101241553_band-1_class-42.npy
# keeping... training_data_v1/id-101241553_band-2_class-42.npy
# keeping... training_data_v1/id-101241553_band-3_class-42.npy
# keeping... training_data_v1/id-101241553_band-4_class-42.npy
# keeping... training_data_v1/id-101241553_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101280621_band-0_class-15.npy
# keeping... training_data_v1/id-101280621_band-1_class-15.npy
# keeping... training_data_v1/id-101280621_band-2_class-15.npy
# keeping... training_data_v1/id-101280621_band-3_class-15.npy
# keeping... training_data_v1/id-101280621_band-4_class-15.npy
# keeping... training_data_v1/id-101280621_band-5_class-15.npy
# keeping... training_data_v1/id-101298_band-0_class-90.npy
# keeping... training_data_v1/id-101298_band-1_class-90.npy
# keeping... training_data_v1/id-101298_band-2_class-90.npy
# keeping... training_data_v1/id-101298_band-3_class-90.npy
# keeping... training_data_v1/id-101298_band-4_class-90.npy
# keeping... training_data_v1/id-101298_band-5_class-90.npy
# keeping... training_data_v1/id-101310071_band-0_class-42.npy
# keeping... training_data_v1/id-101310071_band-1_class-42.npy
# keeping... training_data_v1/id-101310071_band-2_class-42.npy
# keeping... training_data_v1/id-101310071_band-3_class-42.npy
# keeping... training_data_v1/id-101310071_band-4_class-42.npy
# keeping... training_data_v1/id-101310071_band-5_class-42.npy
# keeping... training_data_v1/id-101310348_band-0_class-15.npy
# keeping... training_data_v1/id-101310348_band-1_class-15.npy
# keeping... training_data_v1/id-101310348_band-2_class-15.npy
# keeping... training_data_v1/id-101310348_band-3_class-15.npy
# keeping... training_data_v1/id-101310348_band-4_class-15.npy
# keeping... training_data_v1/id-101310348_band-5_class-15.npy
# keeping... training_data_v1/id-101323749_band-0_class-62.npy
# keeping... training_data_v1/id-101323749_band-1_class-62.npy
# keeping... training_data_v1/id-101323749_band-2_class-62.npy
# keeping... training_data_v1/id-101323749_band-3_class-62.npy
# keeping... training_data_v1/id-101323749_band-4_class-62.npy
# keeping... training_data_v1/id-101323749_band-5_class-62.npy
# keeping... training_data_v1/id-101326940_band-0_class-42.npy
# keeping... training_data_v1/id-101326940_band-1_class-42.npy
# keeping... training_data_v1/id-101326940_band-2_class-42.npy
# keeping... training_data_v1/id-101326940_band-3_class-42.npy
# keeping... training_data_v1/id-101326940_band-4_class-42.npy
# keeping... training_data_v1/id-101326940_band-5_class-42.npy
# keeping... training_data_v1/id-101349530_band-0_class-90.npy
# keeping... training_data_v1/id-101349530_band-1_class-90.npy
# keeping... training_data_v1/id-101349530_band-2_class-90.npy
# keeping... training_data_v1/id-101349530_band-3_class-90.npy
# keeping... training_data_v1/id-101349530_band-4_class-90.npy
# keeping... training_data_v1/id-101349530_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101376210_band-0_class-90.npy
# keeping... training_data_v1/id-101376210_band-1_class-90.npy
# keeping... training_data_v1/id-101376210_band-2_class-90.npy
# keeping... training_data_v1/id-101376210_band-3_class-90.npy
# keeping... training_data_v1/id-101376210_band-4_class-90.npy
# keeping... training_data_v1/id-101376210_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101460016_band-0_class-52.npy
# keeping... training_data_v1/id-101460016_band-1_class-52.npy
# keeping... training_data_v1/id-101460016_band-2_class-52.npy
# keeping... training_data_v1/id-101460016_band-3_class-52.npy
# keeping... training_data_v1/id-101460016_band-4_class-52.npy
# keeping... training_data_v1/id-101460016_band-5_class-52.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101489_band-0_class-42.npy
# keeping... training_data_v1/id-101489_band-1_class-42.npy
# keeping... training_data_v1/id-101489_band-2_class-42.npy
# keeping... training_data_v1/id-101489_band-3_class-42.npy
# keeping... training_data_v1/id-101489_band-4_class-42.npy
# keeping... training_data_v1/id-101489_band-5_class-42.npy
# keeping... training_data_v1/id-101508_band-0_class-90.npy
# keeping... training_data_v1/id-101508_band-1_class-90.npy
# keeping... training_data_v1/id-101508_band-2_class-90.npy
# keeping... training_data_v1/id-101508_band-3_class-90.npy
# keeping... training_data_v1/id-101508_band-4_class-90.npy
# keeping... training_data_v1/id-101508_band-5_class-90.npy
# keeping... training_data_v1/id-101547129_band-0_class-90.npy
# keeping... training_data_v1/id-101547129_band-1_class-90.npy
# keeping... training_data_v1/id-101547129_band-2_class-90.npy
# keeping... training_data_v1/id-101547129_band-3_class-90.npy
# keeping... training_data_v1/id-101547129_band-4_class-90.npy
# keeping... training_data_v1/id-101547129_band-5_class-90.npy
# keeping... training_data_v1/id-101575716_band-0_class-52.npy
# keeping... training_data_v1/id-101575716_band-1_class-52.npy
# keeping... training_data_v1/id-101575716_band-2_class-52.npy
# keeping... training_data_v1/id-101575716_band-3_class-52.npy
# keeping... training_data_v1/id-101575716_band-4_class-52.npy
# keeping... training_data_v1/id-101575716_band-5_class-52.npy
# keeping... training_data_v1/id-101595704_band-0_class-42.npy
# keeping... training_data_v1/id-101595704_band-1_class-42.npy
# keeping... training_data_v1/id-101595704_band-2_class-42.npy
# keeping... training_data_v1/id-101595704_band-3_class-42.npy
# keeping... training_data_v1/id-101595704_band-4_class-42.npy
# keeping... training_data_v1/id-101595704_band-5_class-42.npy
# keeping... training_data_v1/id-101610505_band-0_class-15.npy
# keeping... training_data_v1/id-101610505_band-1_class-15.npy
# keeping... training_data_v1/id-101610505_band-2_class-15.npy
# keeping... training_data_v1/id-101610505_band-3_class-15.npy
# keeping... training_data_v1/id-101610505_band-4_class-15.npy
# keeping... training_data_v1/id-101610505_band-5_class-15.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101631565_band-0_class-90.npy
# keeping... training_data_v1/id-101631565_band-1_class-90.npy
# keeping... training_data_v1/id-101631565_band-2_class-90.npy
# keeping... training_data_v1/id-101631565_band-3_class-90.npy
# keeping... training_data_v1/id-101631565_band-4_class-90.npy
# keeping... training_data_v1/id-101631565_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101637641_band-0_class-42.npy
# keeping... training_data_v1/id-101637641_band-1_class-42.npy
# keeping... training_data_v1/id-101637641_band-2_class-42.npy
# keeping... training_data_v1/id-101637641_band-3_class-42.npy
# keeping... training_data_v1/id-101637641_band-4_class-42.npy
# keeping... training_data_v1/id-101637641_band-5_class-42.npy
# keeping... training_data_v1/id-101652534_band-0_class-90.npy
# keeping... training_data_v1/id-101652534_band-1_class-90.npy
# keeping... training_data_v1/id-101652534_band-2_class-90.npy
# keeping... training_data_v1/id-101652534_band-3_class-90.npy
# keeping... training_data_v1/id-101652534_band-4_class-90.npy
# keeping... training_data_v1/id-101652534_band-5_class-90.npy
# keeping... training_data_v1/id-101675670_band-0_class-95.npy
# keeping... training_data_v1/id-101675670_band-1_class-95.npy
# keeping... training_data_v1/id-101675670_band-2_class-95.npy
# keeping... training_data_v1/id-101675670_band-3_class-95.npy
# keeping... training_data_v1/id-101675670_band-4_class-95.npy
# keeping... training_data_v1/id-101675670_band-5_class-95.npy
# keeping... training_data_v1/id-101679595_band-0_class-15.npy
# keeping... training_data_v1/id-101679595_band-1_class-15.npy
# keeping... training_data_v1/id-101679595_band-2_class-15.npy
# keeping... training_data_v1/id-101679595_band-3_class-15.npy
# keeping... training_data_v1/id-101679595_band-4_class-15.npy
# keeping... training_data_v1/id-101679595_band-5_class-15.npy
# keeping... training_data_v1/id-101712254_band-0_class-42.npy
# keeping... training_data_v1/id-101712254_band-1_class-42.npy
# keeping... training_data_v1/id-101712254_band-2_class-42.npy
# keeping... training_data_v1/id-101712254_band-3_class-42.npy
# keeping... training_data_v1/id-101712254_band-4_class-42.npy
# keeping... training_data_v1/id-101712254_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101790771_band-0_class-15.npy
# keeping... training_data_v1/id-101790771_band-1_class-15.npy
# keeping... training_data_v1/id-101790771_band-2_class-15.npy
# keeping... training_data_v1/id-101790771_band-3_class-15.npy
# keeping... training_data_v1/id-101790771_band-4_class-15.npy
# keeping... training_data_v1/id-101790771_band-5_class-15.npy
# keeping... training_data_v1/id-101796890_band-0_class-62.npy
# keeping... training_data_v1/id-101796890_band-1_class-62.npy
# keeping... training_data_v1/id-101796890_band-2_class-62.npy
# keeping... training_data_v1/id-101796890_band-3_class-62.npy
# keeping... training_data_v1/id-101796890_band-4_class-62.npy
# keeping... training_data_v1/id-101796890_band-5_class-62.npy
# keeping... training_data_v1/id-101806291_band-0_class-15.npy
# keeping... training_data_v1/id-101806291_band-1_class-15.npy
# keeping... training_data_v1/id-101806291_band-2_class-15.npy
# keeping... training_data_v1/id-101806291_band-3_class-15.npy
# keeping... training_data_v1/id-101806291_band-4_class-15.npy
# keeping... training_data_v1/id-101806291_band-5_class-15.npy
# keeping... training_data_v1/id-101816124_band-0_class-88.npy
# keeping... training_data_v1/id-101816124_band-1_class-88.npy
# keeping... training_data_v1/id-101816124_band-2_class-88.npy
# keeping... training_data_v1/id-101816124_band-3_class-88.npy
# keeping... training_data_v1/id-101816124_band-4_class-88.npy
# keeping... training_data_v1/id-101816124_band-5_class-88.npy
# keeping... training_data_v1/id-101870045_band-0_class-90.npy
# keeping... training_data_v1/id-101870045_band-1_class-90.npy
# keeping... training_data_v1/id-101870045_band-2_class-90.npy
# keeping... training_data_v1/id-101870045_band-3_class-90.npy
# keeping... training_data_v1/id-101870045_band-4_class-90.npy
# keeping... training_data_v1/id-101870045_band-5_class-90.npy
# keeping... training_data_v1/id-101879101_band-0_class-15.npy
# keeping... training_data_v1/id-101879101_band-1_class-15.npy
# keeping... training_data_v1/id-101879101_band-2_class-15.npy
# keeping... training_data_v1/id-101879101_band-3_class-15.npy
# keeping... training_data_v1/id-101879101_band-4_class-15.npy
# keeping... training_data_v1/id-101879101_band-5_class-15.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-1019335_band-0_class-90.npy
# keeping... training_data_v1/id-1019335_band-1_class-90.npy
# keeping... training_data_v1/id-1019335_band-2_class-90.npy
# keeping... training_data_v1/id-1019335_band-3_class-90.npy
# keeping... training_data_v1/id-1019335_band-4_class-90.npy
# keeping... training_data_v1/id-1019335_band-5_class-90.npy
# keeping... training_data_v1/id-101955355_band-0_class-90.npy
# keeping... training_data_v1/id-101955355_band-1_class-90.npy
# keeping... training_data_v1/id-101955355_band-2_class-90.npy
# keeping... training_data_v1/id-101955355_band-3_class-90.npy
# keeping... training_data_v1/id-101955355_band-4_class-90.npy
# keeping... training_data_v1/id-101955355_band-5_class-90.npy
# keeping... training_data_v1/id-10196321_band-0_class-90.npy
# keeping... training_data_v1/id-10196321_band-1_class-90.npy
# keeping... training_data_v1/id-10196321_band-2_class-90.npy
# keeping... training_data_v1/id-10196321_band-3_class-90.npy
# keeping... training_data_v1/id-10196321_band-4_class-90.npy
# keeping... training_data_v1/id-10196321_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-101990451_band-0_class-42.npy
# keeping... training_data_v1/id-101990451_band-1_class-42.npy
# keeping... training_data_v1/id-101990451_band-2_class-42.npy
# keeping... training_data_v1/id-101990451_band-3_class-42.npy
# keeping... training_data_v1/id-101990451_band-4_class-42.npy
# keeping... training_data_v1/id-101990451_band-5_class-42.npy
# keeping... training_data_v1/id-102004011_band-0_class-90.npy
# keeping... training_data_v1/id-102004011_band-1_class-90.npy
# keeping... training_data_v1/id-102004011_band-2_class-90.npy
# keeping... training_data_v1/id-102004011_band-3_class-90.npy
# keeping... training_data_v1/id-102004011_band-4_class-90.npy
# keeping... training_data_v1/id-102004011_band-5_class-90.npy
# keeping... training_data_v1/id-102007339_band-0_class-90.npy
# keeping... training_data_v1/id-102007339_band-1_class-90.npy
# keeping... training_data_v1/id-102007339_band-2_class-90.npy
# keeping... training_data_v1/id-102007339_band-3_class-90.npy
# keeping... training_data_v1/id-102007339_band-4_class-90.npy
# keeping... training_data_v1/id-102007339_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102036_band-0_class-42.npy
# keeping... training_data_v1/id-102036_band-1_class-42.npy
# keeping... training_data_v1/id-102036_band-2_class-42.npy
# keeping... training_data_v1/id-102036_band-3_class-42.npy
# keeping... training_data_v1/id-102036_band-4_class-42.npy
# keeping... training_data_v1/id-102036_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102048510_band-0_class-90.npy
# keeping... training_data_v1/id-102048510_band-1_class-90.npy
# keeping... training_data_v1/id-102048510_band-2_class-90.npy
# keeping... training_data_v1/id-102048510_band-3_class-90.npy
# keeping... training_data_v1/id-102048510_band-4_class-90.npy
# keeping... training_data_v1/id-102048510_band-5_class-90.npy
# keeping... training_data_v1/id-10208103_band-0_class-90.npy
# keeping... training_data_v1/id-10208103_band-1_class-90.npy
# keeping... training_data_v1/id-10208103_band-2_class-90.npy
# keeping... training_data_v1/id-10208103_band-3_class-90.npy
# keeping... training_data_v1/id-10208103_band-4_class-90.npy
# keeping... training_data_v1/id-10208103_band-5_class-90.npy
# keeping... training_data_v1/id-102093938_band-0_class-42.npy
# keeping... training_data_v1/id-102093938_band-1_class-42.npy
# keeping... training_data_v1/id-102093938_band-2_class-42.npy
# keeping... training_data_v1/id-102093938_band-3_class-42.npy
# keeping... training_data_v1/id-102093938_band-4_class-42.npy
# keeping... training_data_v1/id-102093938_band-5_class-42.npy
# keeping... training_data_v1/id-102096317_band-0_class-42.npy
# keeping... training_data_v1/id-102096317_band-1_class-42.npy
# keeping... training_data_v1/id-102096317_band-2_class-42.npy
# keeping... training_data_v1/id-102096317_band-3_class-42.npy
# keeping... training_data_v1/id-102096317_band-4_class-42.npy
# keeping... training_data_v1/id-102096317_band-5_class-42.npy
# keeping... training_data_v1/id-102134564_band-0_class-62.npy
# keeping... training_data_v1/id-102134564_band-1_class-62.npy
# keeping... training_data_v1/id-102134564_band-2_class-62.npy
# keeping... training_data_v1/id-102134564_band-3_class-62.npy
# keeping... training_data_v1/id-102134564_band-4_class-62.npy
# keeping... training_data_v1/id-102134564_band-5_class-62.npy
# keeping... training_data_v1/id-102178865_band-0_class-90.npy
# [=                                                                       ]   2%
# keeping... training_data_v1/id-102178865_band-1_class-90.npy
# keeping... training_data_v1/id-102178865_band-2_class-90.npy
# keeping... training_data_v1/id-102178865_band-3_class-90.npy
# keeping... training_data_v1/id-102178865_band-4_class-90.npy
# keeping... training_data_v1/id-102178865_band-5_class-90.npy
# keeping... training_data_v1/id-102203881_band-0_class-15.npy
# keeping... training_data_v1/id-102203881_band-1_class-15.npy
# keeping... training_data_v1/id-102203881_band-2_class-15.npy
# keeping... training_data_v1/id-102203881_band-3_class-15.npy
# keeping... training_data_v1/id-102203881_band-4_class-15.npy
# keeping... training_data_v1/id-102203881_band-5_class-15.npy
# keeping... training_data_v1/id-102219985_band-0_class-62.npy
# keeping... training_data_v1/id-102219985_band-1_class-62.npy
# keeping... training_data_v1/id-102219985_band-2_class-62.npy
# keeping... training_data_v1/id-102219985_band-3_class-62.npy
# keeping... training_data_v1/id-102219985_band-4_class-62.npy
# keeping... training_data_v1/id-102219985_band-5_class-62.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102302473_band-0_class-90.npy
# keeping... training_data_v1/id-102302473_band-1_class-90.npy
# keeping... training_data_v1/id-102302473_band-2_class-90.npy
# keeping... training_data_v1/id-102302473_band-3_class-90.npy
# keeping... training_data_v1/id-102302473_band-4_class-90.npy
# keeping... training_data_v1/id-102302473_band-5_class-90.npy
# keeping... training_data_v1/id-102315326_band-0_class-42.npy
# keeping... training_data_v1/id-102315326_band-1_class-42.npy
# keeping... training_data_v1/id-102315326_band-2_class-42.npy
# keeping... training_data_v1/id-102315326_band-3_class-42.npy
# keeping... training_data_v1/id-102315326_band-4_class-42.npy
# keeping... training_data_v1/id-102315326_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102336134_band-0_class-95.npy
# keeping... training_data_v1/id-102336134_band-1_class-95.npy
# keeping... training_data_v1/id-102336134_band-2_class-95.npy
# keeping... training_data_v1/id-102336134_band-3_class-95.npy
# keeping... training_data_v1/id-102336134_band-4_class-95.npy
# keeping... training_data_v1/id-102336134_band-5_class-95.npy
# keeping... training_data_v1/id-102337497_band-0_class-90.npy
# keeping... training_data_v1/id-102337497_band-1_class-90.npy
# keeping... training_data_v1/id-102337497_band-2_class-90.npy
# keeping... training_data_v1/id-102337497_band-3_class-90.npy
# keeping... training_data_v1/id-102337497_band-4_class-90.npy
# keeping... training_data_v1/id-102337497_band-5_class-90.npy
# keeping... training_data_v1/id-102343_band-0_class-67.npy
# keeping... training_data_v1/id-102343_band-1_class-67.npy
# keeping... training_data_v1/id-102343_band-2_class-67.npy
# keeping... training_data_v1/id-102343_band-3_class-67.npy
# keeping... training_data_v1/id-102343_band-4_class-67.npy
# keeping... training_data_v1/id-102343_band-5_class-67.npy
# keeping... training_data_v1/id-102350999_band-0_class-42.npy
# keeping... training_data_v1/id-102350999_band-1_class-42.npy
# keeping... training_data_v1/id-102350999_band-2_class-42.npy
# keeping... training_data_v1/id-102350999_band-3_class-42.npy
# keeping... training_data_v1/id-102350999_band-4_class-42.npy
# keeping... training_data_v1/id-102350999_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102363_band-0_class-90.npy
# keeping... training_data_v1/id-102363_band-1_class-90.npy
# keeping... training_data_v1/id-102363_band-2_class-90.npy
# keeping... training_data_v1/id-102363_band-3_class-90.npy
# keeping... training_data_v1/id-102363_band-4_class-90.npy
# keeping... training_data_v1/id-102363_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102389747_band-0_class-90.npy
# keeping... training_data_v1/id-102389747_band-1_class-90.npy
# keeping... training_data_v1/id-102389747_band-2_class-90.npy
# keeping... training_data_v1/id-102389747_band-3_class-90.npy
# keeping... training_data_v1/id-102389747_band-4_class-90.npy
# keeping... training_data_v1/id-102389747_band-5_class-90.npy
# keeping... training_data_v1/id-102404483_band-0_class-90.npy
# keeping... training_data_v1/id-102404483_band-1_class-90.npy
# keeping... training_data_v1/id-102404483_band-2_class-90.npy
# keeping... training_data_v1/id-102404483_band-3_class-90.npy
# keeping... training_data_v1/id-102404483_band-4_class-90.npy
# keeping... training_data_v1/id-102404483_band-5_class-90.npy
# keeping... training_data_v1/id-102415062_band-0_class-67.npy
# keeping... training_data_v1/id-102415062_band-1_class-67.npy
# keeping... training_data_v1/id-102415062_band-2_class-67.npy
# keeping... training_data_v1/id-102415062_band-3_class-67.npy
# keeping... training_data_v1/id-102415062_band-4_class-67.npy
# keeping... training_data_v1/id-102415062_band-5_class-67.npy
# keeping... training_data_v1/id-102417599_band-0_class-42.npy
# keeping... training_data_v1/id-102417599_band-1_class-42.npy
# keeping... training_data_v1/id-102417599_band-2_class-42.npy
# keeping... training_data_v1/id-102417599_band-3_class-42.npy
# keeping... training_data_v1/id-102417599_band-4_class-42.npy
# keeping... training_data_v1/id-102417599_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102467299_band-0_class-90.npy
# keeping... training_data_v1/id-102467299_band-1_class-90.npy
# keeping... training_data_v1/id-102467299_band-2_class-90.npy
# keeping... training_data_v1/id-102467299_band-3_class-90.npy
# keeping... training_data_v1/id-102467299_band-4_class-90.npy
# keeping... training_data_v1/id-102467299_band-5_class-90.npy
# keeping... training_data_v1/id-102479413_band-0_class-42.npy
# keeping... training_data_v1/id-102479413_band-1_class-42.npy
# keeping... training_data_v1/id-102479413_band-2_class-42.npy
# keeping... training_data_v1/id-102479413_band-3_class-42.npy
# keeping... training_data_v1/id-102479413_band-4_class-42.npy
# keeping... training_data_v1/id-102479413_band-5_class-42.npy
# keeping... training_data_v1/id-102479522_band-0_class-90.npy
# keeping... training_data_v1/id-102479522_band-1_class-90.npy
# keeping... training_data_v1/id-102479522_band-2_class-90.npy
# keeping... training_data_v1/id-102479522_band-3_class-90.npy
# keeping... training_data_v1/id-102479522_band-4_class-90.npy
# keeping... training_data_v1/id-102479522_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102496947_band-0_class-42.npy
# keeping... training_data_v1/id-102496947_band-1_class-42.npy
# keeping... training_data_v1/id-102496947_band-2_class-42.npy
# keeping... training_data_v1/id-102496947_band-3_class-42.npy
# keeping... training_data_v1/id-102496947_band-4_class-42.npy
# keeping... training_data_v1/id-102496947_band-5_class-42.npy
# keeping... training_data_v1/id-102506887_band-0_class-90.npy
# keeping... training_data_v1/id-102506887_band-1_class-90.npy
# keeping... training_data_v1/id-102506887_band-2_class-90.npy
# keeping... training_data_v1/id-102506887_band-3_class-90.npy
# keeping... training_data_v1/id-102506887_band-4_class-90.npy
# keeping... training_data_v1/id-102506887_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102529486_band-0_class-90.npy
# keeping... training_data_v1/id-102529486_band-1_class-90.npy
# keeping... training_data_v1/id-102529486_band-2_class-90.npy
# keeping... training_data_v1/id-102529486_band-3_class-90.npy
# keeping... training_data_v1/id-102529486_band-4_class-90.npy
# keeping... training_data_v1/id-102529486_band-5_class-90.npy
# keeping... training_data_v1/id-102540572_band-0_class-52.npy
# keeping... training_data_v1/id-102540572_band-1_class-52.npy
# keeping... training_data_v1/id-102540572_band-2_class-52.npy
# keeping... training_data_v1/id-102540572_band-3_class-52.npy
# keeping... training_data_v1/id-102540572_band-4_class-52.npy
# keeping... training_data_v1/id-102540572_band-5_class-52.npy
# keeping... training_data_v1/id-102551107_band-0_class-64.npy
# keeping... training_data_v1/id-102551107_band-1_class-64.npy
# keeping... training_data_v1/id-102551107_band-2_class-64.npy
# keeping... training_data_v1/id-102551107_band-3_class-64.npy
# keeping... training_data_v1/id-102551107_band-4_class-64.npy
# keeping... training_data_v1/id-102551107_band-5_class-64.npy
# keeping... training_data_v1/id-102560576_band-0_class-15.npy
# keeping... training_data_v1/id-102560576_band-1_class-15.npy
# keeping... training_data_v1/id-102560576_band-2_class-15.npy
# keeping... training_data_v1/id-102560576_band-3_class-15.npy
# keeping... training_data_v1/id-102560576_band-4_class-15.npy
# keeping... training_data_v1/id-102560576_band-5_class-15.npy
# keeping... training_data_v1/id-102599855_band-0_class-64.npy
# keeping... training_data_v1/id-102599855_band-1_class-64.npy
# keeping... training_data_v1/id-102599855_band-2_class-64.npy
# keeping... training_data_v1/id-102599855_band-3_class-64.npy
# keeping... training_data_v1/id-102599855_band-4_class-64.npy
# keeping... training_data_v1/id-102599855_band-5_class-64.npy
# keeping... training_data_v1/id-102601034_band-0_class-88.npy
# keeping... training_data_v1/id-102601034_band-1_class-88.npy
# keeping... training_data_v1/id-102601034_band-2_class-88.npy
# keeping... training_data_v1/id-102601034_band-3_class-88.npy
# keeping... training_data_v1/id-102601034_band-4_class-88.npy
# keeping... training_data_v1/id-102601034_band-5_class-88.npy
# keeping... training_data_v1/id-102605941_band-0_class-15.npy
# keeping... training_data_v1/id-102605941_band-1_class-15.npy
# keeping... training_data_v1/id-102605941_band-2_class-15.npy
# keeping... training_data_v1/id-102605941_band-3_class-15.npy
# keeping... training_data_v1/id-102605941_band-4_class-15.npy
# keeping... training_data_v1/id-102605941_band-5_class-15.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102631354_band-0_class-15.npy
# keeping... training_data_v1/id-102631354_band-1_class-15.npy
# keeping... training_data_v1/id-102631354_band-2_class-15.npy
# keeping... training_data_v1/id-102631354_band-3_class-15.npy
# keeping... training_data_v1/id-102631354_band-4_class-15.npy
# keeping... training_data_v1/id-102631354_band-5_class-15.npy
# keeping... training_data_v1/id-102667737_band-0_class-42.npy
# keeping... training_data_v1/id-102667737_band-1_class-42.npy
# keeping... training_data_v1/id-102667737_band-2_class-42.npy
# keeping... training_data_v1/id-102667737_band-3_class-42.npy
# keeping... training_data_v1/id-102667737_band-4_class-42.npy
# keeping... training_data_v1/id-102667737_band-5_class-42.npy
# keeping... training_data_v1/id-102692257_band-0_class-90.npy
# keeping... training_data_v1/id-102692257_band-1_class-90.npy
# keeping... training_data_v1/id-102692257_band-2_class-90.npy
# keeping... training_data_v1/id-102692257_band-3_class-90.npy
# keeping... training_data_v1/id-102692257_band-4_class-90.npy
# keeping... training_data_v1/id-102692257_band-5_class-90.npy
# keeping... training_data_v1/id-102700077_band-0_class-42.npy
# keeping... training_data_v1/id-102700077_band-1_class-42.npy
# keeping... training_data_v1/id-102700077_band-2_class-42.npy
# keeping... training_data_v1/id-102700077_band-3_class-42.npy
# keeping... training_data_v1/id-102700077_band-4_class-42.npy
# keeping... training_data_v1/id-102700077_band-5_class-42.npy
# keeping... training_data_v1/id-102745_band-0_class-90.npy
# keeping... training_data_v1/id-102745_band-1_class-90.npy
# keeping... training_data_v1/id-102745_band-2_class-90.npy
# keeping... training_data_v1/id-102745_band-3_class-90.npy
# keeping... training_data_v1/id-102745_band-4_class-90.npy
# keeping... training_data_v1/id-102745_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102772502_band-0_class-90.npy
# keeping... training_data_v1/id-102772502_band-1_class-90.npy
# keeping... training_data_v1/id-102772502_band-2_class-90.npy
# keeping... training_data_v1/id-102772502_band-3_class-90.npy
# keeping... training_data_v1/id-102772502_band-4_class-90.npy
# keeping... training_data_v1/id-102772502_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102854721_band-0_class-62.npy
# keeping... training_data_v1/id-102854721_band-1_class-62.npy
# keeping... training_data_v1/id-102854721_band-2_class-62.npy
# keeping... training_data_v1/id-102854721_band-3_class-62.npy
# keeping... training_data_v1/id-102854721_band-4_class-62.npy
# keeping... training_data_v1/id-102854721_band-5_class-62.npy
# keeping... training_data_v1/id-102864430_band-0_class-42.npy
# keeping... training_data_v1/id-102864430_band-1_class-42.npy
# keeping... training_data_v1/id-102864430_band-2_class-42.npy
# keeping... training_data_v1/id-102864430_band-3_class-42.npy
# keeping... training_data_v1/id-102864430_band-4_class-42.npy
# keeping... training_data_v1/id-102864430_band-5_class-42.npy
# keeping... training_data_v1/id-102864_band-0_class-42.npy
# keeping... training_data_v1/id-102864_band-1_class-42.npy
# keeping... training_data_v1/id-102864_band-2_class-42.npy
# keeping... training_data_v1/id-102864_band-3_class-42.npy
# keeping... training_data_v1/id-102864_band-4_class-42.npy
# keeping... training_data_v1/id-102864_band-5_class-42.npy
# keeping... training_data_v1/id-102869165_band-0_class-90.npy
# keeping... training_data_v1/id-102869165_band-1_class-90.npy
# keeping... training_data_v1/id-102869165_band-2_class-90.npy
# keeping... training_data_v1/id-102869165_band-3_class-90.npy
# keeping... training_data_v1/id-102869165_band-4_class-90.npy
# keeping... training_data_v1/id-102869165_band-5_class-90.npy
# keeping... training_data_v1/id-102872261_band-0_class-90.npy
# keeping... training_data_v1/id-102872261_band-1_class-90.npy
# keeping... training_data_v1/id-102872261_band-2_class-90.npy
# keeping... training_data_v1/id-102872261_band-3_class-90.npy
# keeping... training_data_v1/id-102872261_band-4_class-90.npy
# keeping... training_data_v1/id-102872261_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102924312_band-0_class-42.npy
# keeping... training_data_v1/id-102924312_band-1_class-42.npy
# keeping... training_data_v1/id-102924312_band-2_class-42.npy
# keeping... training_data_v1/id-102924312_band-3_class-42.npy
# keeping... training_data_v1/id-102924312_band-4_class-42.npy
# keeping... training_data_v1/id-102924312_band-5_class-42.npy
# keeping... training_data_v1/id-102954572_band-0_class-67.npy
# keeping... training_data_v1/id-102954572_band-1_class-67.npy
# keeping... training_data_v1/id-102954572_band-2_class-67.npy
# keeping... training_data_v1/id-102954572_band-3_class-67.npy
# keeping... training_data_v1/id-102954572_band-4_class-67.npy
# keeping... training_data_v1/id-102954572_band-5_class-67.npy
# keeping... training_data_v1/id-102971259_band-0_class-42.npy
# keeping... training_data_v1/id-102971259_band-1_class-42.npy
# keeping... training_data_v1/id-102971259_band-2_class-42.npy
# keeping... training_data_v1/id-102971259_band-3_class-42.npy
# keeping... training_data_v1/id-102971259_band-4_class-42.npy
# keeping... training_data_v1/id-102971259_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-102994328_band-0_class-42.npy
# keeping... training_data_v1/id-102994328_band-1_class-42.npy
# keeping... training_data_v1/id-102994328_band-2_class-42.npy
# keeping... training_data_v1/id-102994328_band-3_class-42.npy
# keeping... training_data_v1/id-102994328_band-4_class-42.npy
# keeping... training_data_v1/id-102994328_band-5_class-42.npy
# keeping... training_data_v1/id-102994812_band-0_class-15.npy
# keeping... training_data_v1/id-102994812_band-1_class-15.npy
# keeping... training_data_v1/id-102994812_band-2_class-15.npy
# keeping... training_data_v1/id-102994812_band-3_class-15.npy
# keeping... training_data_v1/id-102994812_band-4_class-15.npy
# keeping... training_data_v1/id-102994812_band-5_class-15.npy
# keeping... training_data_v1/id-102999753_band-0_class-90.npy
# keeping... training_data_v1/id-102999753_band-1_class-90.npy
# keeping... training_data_v1/id-102999753_band-2_class-90.npy
# keeping... training_data_v1/id-102999753_band-3_class-90.npy
# keeping... training_data_v1/id-102999753_band-4_class-90.npy
# keeping... training_data_v1/id-102999753_band-5_class-90.npy
# keeping... training_data_v1/id-103005044_band-0_class-67.npy
# keeping... training_data_v1/id-103005044_band-1_class-67.npy
# keeping... training_data_v1/id-103005044_band-2_class-67.npy
# keeping... training_data_v1/id-103005044_band-3_class-67.npy
# keeping... training_data_v1/id-103005044_band-4_class-67.npy
# keeping... training_data_v1/id-103005044_band-5_class-67.npy
# keeping... training_data_v1/id-103023_band-0_class-90.npy
# keeping... training_data_v1/id-103023_band-1_class-90.npy
# keeping... training_data_v1/id-103023_band-2_class-90.npy
# keeping... training_data_v1/id-103023_band-3_class-90.npy
# keeping... training_data_v1/id-103023_band-4_class-90.npy
# keeping... training_data_v1/id-103023_band-5_class-90.npy
# keeping... training_data_v1/id-103026_band-0_class-42.npy
# keeping... training_data_v1/id-103026_band-1_class-42.npy
# keeping... training_data_v1/id-103026_band-2_class-42.npy
# keeping... training_data_v1/id-103026_band-3_class-42.npy
# keeping... training_data_v1/id-103026_band-4_class-42.npy
# keeping... training_data_v1/id-103026_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-103047716_band-0_class-90.npy
# keeping... training_data_v1/id-103047716_band-1_class-90.npy
# keeping... training_data_v1/id-103047716_band-2_class-90.npy
# keeping... training_data_v1/id-103047716_band-3_class-90.npy
# keeping... training_data_v1/id-103047716_band-4_class-90.npy
# keeping... training_data_v1/id-103047716_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-103100_band-0_class-90.npy
# keeping... training_data_v1/id-103100_band-1_class-90.npy
# keeping... training_data_v1/id-103100_band-2_class-90.npy
# keeping... training_data_v1/id-103100_band-3_class-90.npy
# keeping... training_data_v1/id-103100_band-4_class-90.npy
# keeping... training_data_v1/id-103100_band-5_class-90.npy
# ...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-99114952_band-0_class-42.npy
# keeping... training_data_v1/id-99114952_band-1_class-42.npy
# keeping... training_data_v1/id-99114952_band-2_class-42.npy
# keeping... training_data_v1/id-99114952_band-3_class-42.npy
# keeping... training_data_v1/id-99114952_band-4_class-42.npy
# keeping... training_data_v1/id-99114952_band-5_class-42.npy
# keeping... training_data_v1/id-99115883_band-0_class-15.npy
# keeping... training_data_v1/id-99115883_band-1_class-15.npy
# keeping... training_data_v1/id-99115883_band-2_class-15.npy
# keeping... training_data_v1/id-99115883_band-3_class-15.npy
# keeping... training_data_v1/id-99115883_band-4_class-15.npy
# keeping... training_data_v1/id-99115883_band-5_class-15.npy
# keeping... training_data_v1/id-99158421_band-0_class-90.npy
# keeping... training_data_v1/id-99158421_band-1_class-90.npy
# keeping... training_data_v1/id-99158421_band-2_class-90.npy
# keeping... training_data_v1/id-99158421_band-3_class-90.npy
# keeping... training_data_v1/id-99158421_band-4_class-90.npy
# keeping... training_data_v1/id-99158421_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-99179619_band-0_class-15.npy
# keeping... training_data_v1/id-99179619_band-1_class-15.npy
# keeping... training_data_v1/id-99179619_band-2_class-15.npy
# keeping... training_data_v1/id-99179619_band-3_class-15.npy
# keeping... training_data_v1/id-99179619_band-4_class-15.npy
# keeping... training_data_v1/id-99179619_band-5_class-15.npy
# keeping... training_data_v1/id-99227595_band-0_class-15.npy
# keeping... training_data_v1/id-99227595_band-1_class-15.npy
# keeping... training_data_v1/id-99227595_band-2_class-15.npy
# keeping... training_data_v1/id-99227595_band-3_class-15.npy
# keeping... training_data_v1/id-99227595_band-4_class-15.npy
# keeping... training_data_v1/id-99227595_band-5_class-15.npy
# keeping... training_data_v1/id-99261_band-0_class-90.npy
# keeping... training_data_v1/id-99261_band-1_class-90.npy
# keeping... training_data_v1/id-99261_band-2_class-90.npy
# keeping... training_data_v1/id-99261_band-3_class-90.npy
# keeping... training_data_v1/id-99261_band-4_class-90.npy
# keeping... training_data_v1/id-99261_band-5_class-90.npy
# keeping... training_data_v1/id-99280_band-0_class-62.npy
# keeping... training_data_v1/id-99280_band-1_class-62.npy
# keeping... training_data_v1/id-99280_band-2_class-62.npy
# keeping... training_data_v1/id-99280_band-3_class-62.npy
# keeping... training_data_v1/id-99280_band-4_class-62.npy
# keeping... training_data_v1/id-99280_band-5_class-62.npy
# keeping... training_data_v1/id-99293_band-0_class-90.npy
# keeping... training_data_v1/id-99293_band-1_class-90.npy
# keeping... training_data_v1/id-99293_band-2_class-90.npy
# keeping... training_data_v1/id-99293_band-3_class-90.npy
# keeping... training_data_v1/id-99293_band-4_class-90.npy
# keeping... training_data_v1/id-99293_band-5_class-90.npy
# keeping... training_data_v1/id-99294_band-0_class-90.npy
# keeping... training_data_v1/id-99294_band-1_class-90.npy
# keeping... training_data_v1/id-99294_band-2_class-90.npy
# keeping... training_data_v1/id-99294_band-3_class-90.npy
# keeping... training_data_v1/id-99294_band-4_class-90.npy
# keeping... training_data_v1/id-99294_band-5_class-90.npy
# keeping... training_data_v1/id-99319278_band-0_class-90.npy
# keeping... training_data_v1/id-99319278_band-1_class-90.npy
# keeping... training_data_v1/id-99319278_band-2_class-90.npy
# keeping... training_data_v1/id-99319278_band-3_class-90.npy
# keeping... training_data_v1/id-99319278_band-4_class-90.npy
# keeping... training_data_v1/id-99319278_band-5_class-90.npy
# keeping... training_data_v1/id-99330650_band-0_class-90.npy
# keeping... training_data_v1/id-99330650_band-1_class-90.npy
# keeping... training_data_v1/id-99330650_band-2_class-90.npy
# keeping... training_data_v1/id-99330650_band-3_class-90.npy
# keeping... training_data_v1/id-99330650_band-4_class-90.npy
# keeping... training_data_v1/id-99330650_band-5_class-90.npy
# keeping... training_data_v1/id-99349362_band-0_class-90.npy
# keeping... training_data_v1/id-99349362_band-1_class-90.npy
# keeping... training_data_v1/id-99349362_band-2_class-90.npy
# keeping... training_data_v1/id-99349362_band-3_class-90.npy
# keeping... training_data_v1/id-99349362_band-4_class-90.npy
# keeping... training_data_v1/id-99349362_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-99368145_band-0_class-62.npy
# keeping... training_data_v1/id-99368145_band-1_class-62.npy
# keeping... training_data_v1/id-99368145_band-2_class-62.npy
# keeping... training_data_v1/id-99368145_band-3_class-62.npy
# keeping... training_data_v1/id-99368145_band-4_class-62.npy
# keeping... training_data_v1/id-99368145_band-5_class-62.npy
# keeping... training_data_v1/id-9936_band-0_class-42.npy
# keeping... training_data_v1/id-9936_band-1_class-42.npy
# keeping... training_data_v1/id-9936_band-2_class-42.npy
# keeping... training_data_v1/id-9936_band-3_class-42.npy
# keeping... training_data_v1/id-9936_band-4_class-42.npy
# keeping... training_data_v1/id-9936_band-5_class-42.npy
# keeping... training_data_v1/id-99390548_band-0_class-90.npy
# keeping... training_data_v1/id-99390548_band-1_class-90.npy
# keeping... training_data_v1/id-99390548_band-2_class-90.npy
# keeping... training_data_v1/id-99390548_band-3_class-90.npy
# keeping... training_data_v1/id-99390548_band-4_class-90.npy
# keeping... training_data_v1/id-99390548_band-5_class-90.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-99449747_band-0_class-64.npy
# keeping... training_data_v1/id-99449747_band-1_class-64.npy
# keeping... training_data_v1/id-99449747_band-2_class-64.npy
# keeping... training_data_v1/id-99449747_band-3_class-64.npy
# keeping... training_data_v1/id-99449747_band-4_class-64.npy
# keeping... training_data_v1/id-99449747_band-5_class-64.npy
# keeping... training_data_v1/id-99452_band-0_class-88.npy
# keeping... training_data_v1/id-99452_band-1_class-88.npy
# keeping... training_data_v1/id-99452_band-2_class-88.npy
# keeping... training_data_v1/id-99452_band-3_class-88.npy
# keeping... training_data_v1/id-99452_band-4_class-88.npy
# keeping... training_data_v1/id-99452_band-5_class-88.npy
# keeping... training_data_v1/id-99453348_band-0_class-90.npy
# keeping... training_data_v1/id-99453348_band-1_class-90.npy
# keeping... training_data_v1/id-99453348_band-2_class-90.npy
# keeping... training_data_v1/id-99453348_band-3_class-90.npy
# keeping... training_data_v1/id-99453348_band-4_class-90.npy
# keeping... training_data_v1/id-99453348_band-5_class-90.npy
# keeping... training_data_v1/id-99468282_band-0_class-15.npy
# keeping... training_data_v1/id-99468282_band-1_class-15.npy
# keeping... training_data_v1/id-99468282_band-2_class-15.npy
# keeping... training_data_v1/id-99468282_band-3_class-15.npy
# keeping... training_data_v1/id-99468282_band-4_class-15.npy
# keeping... training_data_v1/id-99468282_band-5_class-15.npy
# keeping... training_data_v1/id-99507753_band-0_class-95.npy
# keeping... training_data_v1/id-99507753_band-1_class-95.npy
# keeping... training_data_v1/id-99507753_band-2_class-95.npy
# keeping... training_data_v1/id-99507753_band-3_class-95.npy
# keeping... training_data_v1/id-99507753_band-4_class-95.npy
# keeping... training_data_v1/id-99507753_band-5_class-95.npy
# keeping... training_data_v1/id-99523947_band-0_class-90.npy
# keeping... training_data_v1/id-99523947_band-1_class-90.npy
# keeping... training_data_v1/id-99523947_band-2_class-90.npy
# keeping... training_data_v1/id-99523947_band-3_class-90.npy
# keeping... training_data_v1/id-99523947_band-4_class-90.npy
# keeping... training_data_v1/id-99523947_band-5_class-90.npy
# keeping... training_data_v1/id-99538591_band-0_class-62.npy
# keeping... training_data_v1/id-99538591_band-1_class-62.npy
# keeping... training_data_v1/id-99538591_band-2_class-62.npy
# keeping... training_data_v1/id-99538591_band-3_class-62.npy
# keeping... training_data_v1/id-99538591_band-4_class-62.npy
# keeping... training_data_v1/id-99538591_band-5_class-62.npy
# keeping... training_data_v1/id-99550872_band-0_class-15.npy
# keeping... training_data_v1/id-99550872_band-1_class-15.npy
# keeping... training_data_v1/id-99550872_band-2_class-15.npy
# keeping... training_data_v1/id-99550872_band-3_class-15.npy
# keeping... training_data_v1/id-99550872_band-4_class-15.npy
# keeping... training_data_v1/id-99550872_band-5_class-15.npy
# keeping... training_data_v1/id-99554108_band-0_class-95.npy
# keeping... training_data_v1/id-99554108_band-1_class-95.npy
# keeping... training_data_v1/id-99554108_band-2_class-95.npy
# keeping... training_data_v1/id-99554108_band-3_class-95.npy
# keeping... training_data_v1/id-99554108_band-4_class-95.npy
# keeping... training_data_v1/id-99554108_band-5_class-95.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-99642_band-0_class-90.npy
# keeping... training_data_v1/id-99642_band-1_class-90.npy
# keeping... training_data_v1/id-99642_band-2_class-90.npy
# keeping... training_data_v1/id-99642_band-3_class-90.npy
# keeping... training_data_v1/id-99642_band-4_class-90.npy
# keeping... training_data_v1/id-99642_band-5_class-90.npy
# keeping... training_data_v1/id-99660133_band-0_class-90.npy
# keeping... training_data_v1/id-99660133_band-1_class-90.npy
# keeping... training_data_v1/id-99660133_band-2_class-90.npy
# keeping... training_data_v1/id-99660133_band-3_class-90.npy
# keeping... training_data_v1/id-99660133_band-4_class-90.npy
# keeping... training_data_v1/id-99660133_band-5_class-90.npy
# keeping... training_data_v1/id-99702363_band-0_class-15.npy
# keeping... training_data_v1/id-99702363_band-1_class-15.npy
# keeping... training_data_v1/id-99702363_band-2_class-15.npy
# keeping... training_data_v1/id-99702363_band-3_class-15.npy
# keeping... training_data_v1/id-99702363_band-4_class-15.npy
# keeping... training_data_v1/id-99702363_band-5_class-15.npy
# keeping... training_data_v1/id-99715839_band-0_class-42.npy
# keeping... training_data_v1/id-99715839_band-1_class-42.npy
# keeping... training_data_v1/id-99715839_band-2_class-42.npy
# keeping... training_data_v1/id-99715839_band-3_class-42.npy
# keeping... training_data_v1/id-99715839_band-4_class-42.npy
# keeping... training_data_v1/id-99715839_band-5_class-42.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-9974082_band-0_class-90.npy
# keeping... training_data_v1/id-9974082_band-1_class-90.npy
# keeping... training_data_v1/id-9974082_band-2_class-90.npy
# keeping... training_data_v1/id-9974082_band-3_class-90.npy
# keeping... training_data_v1/id-9974082_band-4_class-90.npy
# keeping... training_data_v1/id-9974082_band-5_class-90.npy
# keeping... training_data_v1/id-99755210_band-0_class-42.npy
# keeping... training_data_v1/id-99755210_band-1_class-42.npy
# keeping... training_data_v1/id-99755210_band-2_class-42.npy
# keeping... training_data_v1/id-99755210_band-3_class-42.npy
# keeping... training_data_v1/id-99755210_band-4_class-42.npy
# keeping... training_data_v1/id-99755210_band-5_class-42.npy
# keeping... training_data_v1/id-99761129_band-0_class-42.npy
# keeping... training_data_v1/id-99761129_band-1_class-42.npy
# keeping... training_data_v1/id-99761129_band-2_class-42.npy
# keeping... training_data_v1/id-99761129_band-3_class-42.npy
# keeping... training_data_v1/id-99761129_band-4_class-42.npy
# keeping... training_data_v1/id-99761129_band-5_class-42.npy
# keeping... training_data_v1/id-99780766_band-0_class-95.npy
# keeping... training_data_v1/id-99780766_band-1_class-95.npy
# keeping... training_data_v1/id-99780766_band-2_class-95.npy
# keeping... training_data_v1/id-99780766_band-3_class-95.npy
# keeping... training_data_v1/id-99780766_band-4_class-95.npy
# keeping... training_data_v1/id-99780766_band-5_class-95.npy
# keeping... training_data_v1/id-9978123_band-0_class-42.npy
# keeping... training_data_v1/id-9978123_band-1_class-42.npy
# keeping... training_data_v1/id-9978123_band-2_class-42.npy
# keeping... training_data_v1/id-9978123_band-3_class-42.npy
# keeping... training_data_v1/id-9978123_band-4_class-42.npy
# keeping... training_data_v1/id-9978123_band-5_class-42.npy
# keeping... training_data_v1/id-99801307_band-0_class-42.npy
# keeping... training_data_v1/id-99801307_band-1_class-42.npy
# keeping... training_data_v1/id-99801307_band-2_class-42.npy
# keeping... training_data_v1/id-99801307_band-3_class-42.npy
# keeping... training_data_v1/id-99801307_band-4_class-42.npy
# keeping... training_data_v1/id-99801307_band-5_class-42.npy
# keeping... training_data_v1/id-99815613_band-0_class-95.npy
# keeping... training_data_v1/id-99815613_band-1_class-95.npy
# keeping... training_data_v1/id-99815613_band-2_class-95.npy
# keeping... training_data_v1/id-99815613_band-3_class-95.npy
# keeping... training_data_v1/id-99815613_band-4_class-95.npy
# keeping... training_data_v1/id-99815613_band-5_class-95.npy
# keeping... training_data_v1/id-99836793_band-0_class-67.npy
# keeping... training_data_v1/id-99836793_band-1_class-67.npy
# keeping... training_data_v1/id-99836793_band-2_class-67.npy
# keeping... training_data_v1/id-99836793_band-3_class-67.npy
# keeping... training_data_v1/id-99836793_band-4_class-67.npy
# keeping... training_data_v1/id-99836793_band-5_class-67.npy
# keeping... training_data_v1/id-99854578_band-0_class-88.npy
# keeping... training_data_v1/id-99854578_band-1_class-88.npy
# keeping... training_data_v1/id-99854578_band-2_class-88.npy
# keeping... training_data_v1/id-99854578_band-3_class-88.npy
# keeping... training_data_v1/id-99854578_band-4_class-88.npy
# keeping... training_data_v1/id-99854578_band-5_class-88.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-99862_band-0_class-42.npy
# keeping... training_data_v1/id-99862_band-1_class-42.npy
# keeping... training_data_v1/id-99862_band-2_class-42.npy
# keeping... training_data_v1/id-99862_band-3_class-42.npy
# keeping... training_data_v1/id-99862_band-4_class-42.npy
# keeping... training_data_v1/id-99862_band-5_class-42.npy
# keeping... training_data_v1/id-99863752_band-0_class-42.npy
# keeping... training_data_v1/id-99863752_band-1_class-42.npy
# keeping... training_data_v1/id-99863752_band-2_class-42.npy
# keeping... training_data_v1/id-99863752_band-3_class-42.npy
# keeping... training_data_v1/id-99863752_band-4_class-42.npy
# keeping... training_data_v1/id-99863752_band-5_class-42.npy
# keeping... training_data_v1/id-99886885_band-0_class-42.npy
# keeping... training_data_v1/id-99886885_band-1_class-42.npy
# keeping... training_data_v1/id-99886885_band-2_class-42.npy
# keeping... training_data_v1/id-99886885_band-3_class-42.npy
# keeping... training_data_v1/id-99886885_band-4_class-42.npy
# keeping... training_data_v1/id-99886885_band-5_class-42.npy
# keeping... training_data_v1/id-99906386_band-0_class-88.npy
# keeping... training_data_v1/id-99906386_band-1_class-88.npy
# keeping... training_data_v1/id-99906386_band-2_class-88.npy
# keeping... training_data_v1/id-99906386_band-3_class-88.npy
# keeping... training_data_v1/id-99906386_band-4_class-88.npy
# keeping... training_data_v1/id-99906386_band-5_class-88.npy
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# rejecting...
# keeping... training_data_v1/id-99943177_band-0_class-90.npy
# keeping... training_data_v1/id-99943177_band-1_class-90.npy
# keeping... training_data_v1/id-99943177_band-2_class-90.npy
# keeping... training_data_v1/id-99943177_band-3_class-90.npy
# keeping... training_data_v1/id-99943177_band-4_class-90.npy
# keeping... training_data_v1/id-99943177_band-5_class-90.npy
# keeping... training_data_v1/id-99956418_band-0_class-95.npy
# keeping... training_data_v1/id-99956418_band-1_class-95.npy
# keeping... training_data_v1/id-99956418_band-2_class-95.npy
# keeping... training_data_v1/id-99956418_band-3_class-95.npy
# keeping... training_data_v1/id-99956418_band-4_class-95.npy
# keeping... training_data_v1/id-99956418_band-5_class-95.npy

# %%
IDs_unique = np.unique(IDs)
# list of target IDs, without repetitions

labels_unique = ['' for x in range(len(IDs_unique))]
# list of target labels, without repetitions <indexed as IDs_unique>

print('Number of individual targets: ' + str(len(IDs_unique)))

print(series[0])
print(len(series[0]))
# Out:
# Number of individual targets: 5523
# [[ 5.99642637e+04  1.00640950e+01  8.38450300e+00  0.00000000e+00]
#  [ 5.99682337e+04  1.39473330e+01  1.08811090e+01  0.00000000e+00]
#  [ 5.99991962e+04  7.44600000e-01  1.02430480e+01  0.00000000e+00]
#  [ 6.00291052e+04  5.90130900e+00  8.29292900e+00  0.00000000e+00]
#  [ 6.00800742e+04  1.08659020e+01  1.04812400e+01  0.00000000e+00]
#  [ 6.01400137e+04  1.65579800e+00  1.43844160e+01  0.00000000e+00]
#  [ 6.03783497e+04  1.30674410e+01  1.65489350e+01  0.00000000e+00]
#  [ 6.03821986e+04  4.25549770e+01  1.55467260e+01  0.00000000e+00]
#  [ 6.04650943e+04 -3.27014700e+00  7.11359300e+00  0.00000000e+00]
#  [ 6.04660535e+04  6.65823200e+00  1.44763030e+01  0.00000000e+00]
#  [ 6.05009784e+04  1.10014760e+01  1.02264610e+01  0.00000000e+00]]
# 11

# %% [markdown]
# ## Converting series to images

# %%
# The conversion happens in two steps:
#
# 1) Splitting a time series over a number of pixels (n_pixels)
#
#    The pixel number is chosen arbitrarily, and corresponds to the maximum time duration
#    (i.e. to the duration of the longest series).
#    Hence, a pixel corresponds to a given time interval.
#    The number of pixels (= time) covered by a series is calculated accordingly to its duration.
#    The series are block-averaged (binned) within each time interval (pixel); empty pixels are attributed a 0.
#
# 2) Converting data into a matrix of flux "ratios"
#
#    The ratios of the fluxes of each pixel with respect to the fluxes of all the other pixels
#    are organized in a n_pixels x n_pixels matrix, of the type:
#
#   [1             , (F_1 / F_2)  , ..       , ..       , (F_1 / F_N)  ]
#   [(F_2 / F_1)   , 1            , ..       , ..       , (F_2 / F_N)  ]
#   [..            , ..           , 1        , ..       , ..           ]
#   [(F_N-1 / F_1) , ..           , ..       , 1        , (F_N-1 / F_N)]
#   [(F_N / F_1)   , ..           , ..       , ..       , 1            ]

n_pixels = 32
n_bands  = 6

Duration_MAX = np.max(Duration_MJDs)
# longest duration of time series [MDJ]

deltaT_per_pixel = Duration_MAX / n_pixels
# time interval within a pixel of the new, resampled images [MJD/pixel]
# NOTE: this is defined with respect to the largest duration
# NOTE: final images will have 64 x 64 pixels

data = np.zeros( (len(IDs_unique) , n_pixels , n_pixels , n_bands ) )
# data array < n_targets , image(x,y), bands >
# NOTE: The first dimension corresponds to the number of targets <indexed as IDs_unique>


bar = progressbar.ProgressBar(maxval=n_files, widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()
for i,serie in enumerate(series):

    bar.update(i+1)

    band = int(bands[i])
    # current band index [0 .. 6]

    pixels_image = int(np.ceil( Duration_MJDs[i] / deltaT_per_pixel ))
    # number of pixels that the current image will cover in the resampled image

    MJD = series[i][:,0]
    # Modified Julian Date
    
    F = series[i][:,1]
    # flux  

    F_err = series[i][:,2]
    # flux error
    
    MJD   = np.array(MJD)
    F     = np.array(F)
    F_err = np.array(F_err)

    F_positive = F + abs(np.min(F))
    # shifting values up to have only positive arrays
    
    F_binned = np.zeros((n_pixels))
    # binned flux series
    
    
    # > Binning series - for band b:
      
    for p in range(pixels_image):
    # p = pixel index 

        (indexes_bin,) = np.where( (p*deltaT_per_pixel <= (MJD - MJD[0])) & ((MJD - MJD[0]) < (p+1)*deltaT_per_pixel) )
        # indexes of data points (of series i) within current pixel (bin)
        
        F_binned[p] = float(np.mean( F_positive[indexes_bin] ))
        # flux within current pixel
        
        np.nan_to_num(F_binned,0)
        # (in case no data points were binned, the average is 'nan')

        
    # > Converting series to image - for band b:
        
    data_i = np.zeros((n_pixels,n_pixels,n_bands))
    # flux ratio matrix for source i
    # NOTE: organizing data in a 2D matrix with shape [ len(array) ,  len(array) , channels(= n_bands) ]
 

    for j in range(n_pixels):
    # j = row index
      
        data_i[j,:,band] = ( F_binned[j] / F_binned )

        
    # > Mirroring matrix across the diagonal:
    
    data_i_band = data_i[:,:,band]
    indexes_lower = np.tril_indices(data_i_band.shape[0], -1)
    # indexes of lower part of matrix
    data_i_band[indexes_lower] = data_i_band.T[indexes_lower]
    # mirroring


    # > Removing 'inf' and 'nan':
    data_i_band[np.isinf(data_i_band)] = 0
    np.nan_to_num(data_i_band,0)
    
    
    # > Normalizing image:
    # NOTE: At this point, value are only negative or 0
    data_i_band_norm = (data_i_band + abs(np.min(data_i_band))) / np.max(data_i_band + abs(np.min(data_i_band)))


    # > Organizing data in proper structure:
    
    (t,) = np.where(IDs_unique == IDs[i])
    t = t[0]
    # t = index of target in array of unique IDs
    # NOTE: manipulation is because np.where returns a 1-value array instead of a variable

    labels_unique[t] = labels[i]
    # NOTE: This is over-written 6 times (once per band)
    #       But it doesn't matter since all bands share the same classification 

    band = int(bands[i])
    # NOTE: "bands" is indexed as "IDs"

    data[t,:,:,band] = data_i_band_norm
    # loading image in corresponding unique (object ID, band) slot  
    
    
bar.finish()
  
print('Shape of data: ' + str(data.shape))
# Out:
# [========================================================================] 100%
# Shape of data: (5523, 32, 32, 6)

# %% [markdown]
# ## Display examples of data series of same class over different bands

# %%
# Display some example images

n_display = 18
# max number of images to be displayed

fig = plt.figure(figsize=(15,25))

for t,data_t in (enumerate(data)):
# t = target index
    
    for band in range(data_t.shape[2]):
    # iterating over the bands for target t
    # (they could in principle be different for different targets)

        band = int(band)
        
        image_t_b = data[t,:,:,band]
        # image corresponding to a given target t and band
        
        # Plotting:

        p = t*n_bands + band
        # p = plot counter
        
        plt.subplot(10, 6, p + 1)
        plt.axis('off')

        plt.tight_layout()
        
        vmin,vmax = np.percentile(image_t_b.flatten(),[1,99])
        # min and max are set as percentiles for each image

        plt.imshow(image_t_b, vmin=vmin, vmax=vmax, interpolation='nearest')
        plt.title(str(IDs_unique[t]) + ' | b ' + str(band) + ' | cl ' + labels_unique[t])
        
    if p == (n_display-1): break

# %% [markdown]
# ## Display average images for same class (and same band)

# %%
fig = plt.figure(figsize=(15,35))

labels_list = list(set(labels_unique))
labels_list.sort()
# list of classes in the data


bar = progressbar.ProgressBar(maxval=len(labels_list), widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()
for c in range(len(labels_list)):
# c = index of class_list

    bar.update(c+1)

    for band in range(data_t.shape[2]):
    # iterating over the bands for class c

        band = int(band)
        
        if(band >= n_bands):
            # in case the number of bands has been reduced for the analysis
            continue

        (indexes_c,) = np.where(np.array(labels_unique) == labels_list[c])
        # indexes of targets with label c
    
        median_c_band = np.median(data[indexes_c,:,:,band], axis=(0))
        # median image for class c and band

        
        # Plotting:

        p = c*n_bands + band
        # p = plot counter
        
        plt.subplot(len(labels_list), n_bands, p + 1)
        plt.axis('off')

        plt.tight_layout()

        vmin,vmax = np.percentile(median_c_band.flatten(),[0.1,99.9])
        # min and max are set as percentiles for each image

        plt.imshow(median_c_band, vmin=vmin, vmax=vmax, interpolation='nearest')
        plt.title('cl ' + labels_list[c] + ' | b ' + str(band))

bar.finish()
# Out:
# [========================================================================] 100%

# %% [markdown]
# ## Creating samples

# %%
# Shuffle the samples
shuffled_indexes = np.arange(len(IDs_unique))
np.random.shuffle(shuffled_indexes)

# To reduce the sample size (for testing purposes):
# remove: shuffled_indexes = shuffled_indexes[0:1000]
# remove: n_samples = len(shuffled_indexes)

data = data[shuffled_indexes]
labels_unique = list(np.array(labels_unique)[shuffled_indexes])

n_samples = len(IDs_unique)

# %%
# Splitting in training, validation, and test samples:
data_train = data[:8 * n_samples // 10] # i.e. 80% training
labels_train = labels_unique[:8 * n_samples // 10]

data_valid = data[8 * n_samples // 10:9 * n_samples // 10] # i.e. 10% validation (80->90%)
labels_valid = labels_unique[8 * n_samples // 10:9 * n_samples // 10]

data_test = data[9 * n_samples // 10:] # i.e. 10% testing (90->100%)
labels_test = labels_unique[9 * n_samples // 10:]

#n_train_spiral = len([x for x in labels_train if x == 'spiral'])
#n_train_ellipt = len([x for x in labels_train if x == 'ellipt'])

#n_valid_spiral = len([x for x in labels_valid if x == 'spiral'])
#n_valid_ellipt = len([x for x in labels_valid if x == 'ellipt'])

#n_test_spiral = len([x for x in labels_test if x == 'spiral'])
#n_test_ellipt = len([x for x in labels_test if x == 'ellipt'])

print("Sample Summary")
print("________________________")
print("Total images     | %5s" % len(data))
print("-----------------|------")
print(" '-> Training    | %5s" % len(data_train))
#print("      '-> spiral | %5s (%.1f%%)" % (n_train_spiral , (n_train_spiral/len(data_train)*100.)))
#print("      '-> ellipt | %5s (%.1f%%)" % (n_train_ellipt , (n_train_ellipt/len(data_train)*100.)))
print("-----------------|------")
print(" '-> Validation  | %5s" % len(data_valid))
#print("      '-> spiral | %5s (%.1f%%)" % (n_valid_spiral , (n_valid_spiral/len(data_valid)*100.)))
#print("      '-> ellipt | %5s (%.1f%%)" % (n_valid_ellipt , (n_valid_ellipt/len(data_valid)*100.)))
print("-----------------|------")
print(" '-> Test        | %5s" % len(data_test))
#print("      '-> spiral | %5s (%.1f%%)" % (n_test_spiral , (n_test_spiral/len(data_test)*100.)))
#print("      '-> ellipt | %5s (%.1f%%)" % (n_test_ellipt , (n_test_ellipt/len(data_test)*100.)))

print('')
print('Compare these values with the accuracy of each classifier')
print('If accuracies are similar to the demographics, the classifier is only mirroring the data')
# Out:
# Sample Summary
# ________________________
# Total images     |  5523
# -----------------|------
#  '-> Training    |  4418
# -----------------|------
#  '-> Validation  |   552
# -----------------|------
#  '-> Test        |   553
#
# Compare these values with the accuracy of each classifier
# If accuracies are similar to the demographics, the classifier is only mirroring the data

# %% [markdown]
# ### Converting to 1D for other classifiers

# %%
# Converting to 1D:

# Using only band 0, and compressing dimensions into 1:
data_train_1D = data_train[:,:,:,0].reshape(len(data_train),n_pixels*n_pixels)
data_valid_1D = data_valid[:,:,:,0].reshape(len(data_valid),n_pixels*n_pixels)

labels_train_1D = labels_train
labels_valid_1D = labels_valid 

print('Shape of train 1D       | ' + str(data_train_1D.shape))
print('Shape of valid 1D       | ' + str(data_valid_1D.shape))

print('Shape of label train 1D | ' + str(len(labels_train_1D)))
print('Shape of label valid 1D | ' + str(len(labels_valid_1D)))
# Out:
# Shape of train 1D       | (4418, 1024)
# Shape of valid 1D       | (552, 1024)
# Shape of label train 1D | 4418
# Shape of label valid 1D | 552

# %% [markdown]
# ## > Using scikit-learn / SVM classifier
# Classical Support Vector Machines classifier
# NOTE: The non-linear kernel is extremely slow

# %%
# Classifier
model_svc = LinearSVC()
#model_svc = NuSVC()
model_svc.fit(data_train_1D, labels_train_1D)

# Comparisong with prediction
predicted = model_svc.predict(data_valid_1D)

print("Classification report for %s:\n%s\n"
      % (model_svc, metrics.classification_report(labels_valid_1D, predicted)))
print("Confusion matrix:\n%s" % metrics.confusion_matrix(labels_valid_1D, predicted))
# Out:
# Classification report for LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0):
#               precision    recall  f1-score   support
#
#           15       0.26      0.17      0.20        48
#           42       0.25      0.19      0.22       120
#           52       0.00      0.00      0.00        19
#           62       0.00      0.00      0.00        47
#           64       0.00      0.00      0.00        13
#           67       0.00      0.00      0.00        28
#           88       0.00      0.00      0.00        33
#           90       0.44      0.76      0.55       230
#           95       0.00      0.00      0.00        14
#
#    micro avg       0.37      0.37      0.37       552
#    macro avg       0.10      0.12      0.11       552
# weighted avg       0.26      0.37      0.30       552
#
#
# Confusion matrix:
# [[  8   9   0   0   0   0   0  30   1]
#  [  9  23   0   1   0   1   3  82   1]
#  [  1   3   0   0   0   0   0  15   0]
#  [  0   6   0   0   0   2   2  37   0]
#  [  1   4   0   0   0   0   0   8   0]
#  [  0   4   0   0   0   0   0  24   0]
#  [  2   8   0   2   0   0   0  21   0]
#  [  8  33   0   4   2   3   3 175   2]
#  [  2   2   0   1   0   0   0   9   0]]

# %% [markdown]
# ## > Using scikit learn / Random Forests
# A scikit-learn bagging classifier.

# %%
# Classifier
model_RF = RandomForestClassifier()
model_RF.fit(data_train_1D, labels_train_1D)

# Comparisong with prediction
predicted = model_RF.predict(data_valid_1D)

print("Classification report for %s:\n%s\n"
      % (model_RF, metrics.classification_report(labels_valid_1D, predicted)))
print("Confusion matrix:\n%s" % metrics.confusion_matrix(labels_valid_1D, predicted))
# Out:
# Classification report for RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False):
#               precision    recall  f1-score   support
#
#           15       0.26      0.25      0.25        48
#           42       0.17      0.21      0.19       120
#           52       0.00      0.00      0.00        19
#           62       0.14      0.09      0.11        47
#           64       0.00      0.00      0.00        13
#           67       0.33      0.04      0.06        28
#           88       0.09      0.03      0.05        33
#           90       0.42      0.57      0.49       230
#           95       0.00      0.00      0.00        14
#
#    micro avg       0.32      0.32      0.32       552
#    macro avg       0.16      0.13      0.13       552
# weighted avg       0.27      0.32      0.28       552
#
#
# Confusion matrix:
# [[ 12  17   0   4   0   0   0  14   1]
#  [ 12  25   0   8   0   1   2  72   0]
#  [  0   7   0   0   0   1   0  11   0]
#  [  2  10   1   4   0   0   1  29   0]
#  [  0   3   0   0   0   0   1   9   0]
#  [  2   8   1   1   0   1   0  15   0]
#  [  4   6   1   0   0   0   1  21   0]
#  [ 13  66   1  11   0   0   6 132   1]
#  [  2   3   0   1   0   0   0   8   0]]

# %% [markdown]
# ## > Building a Keras Neural Network classifier

# %%
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution1D
from keras.layers import Convolution2D
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import MaxPool2D
from keras.layers import Dropout

from tensorflow.contrib.layers import maxout

from keras.utils import np_utils
from keras import regularizers
from keras import optimizers
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
n_bands = data_train.shape[-1]

# >> One hot encoding the class values to tranform the vector of class integers into a binary matrix:
int_enc = LabelEncoder()
labels_train_int = int_enc.fit_transform(labels_train)
labels_valid_int = int_enc.fit_transform(labels_valid)
labels_test_int  = int_enc.fit_transform(labels_test)

labels_train_int = np.expand_dims(labels_train_int, axis=1)
labels_valid_int = np.expand_dims(labels_valid_int, axis=1)
labels_test_int  = np.expand_dims(labels_test_int, axis=1)

# Replicating the classification for all the bands:
#labels_train_int = np.repeat(labels_train_int[:,np.newaxis], n_bands, 1)
#labels_valid_int = np.repeat(labels_valid_int[:,np.newaxis], n_bands, 1)
#labels_test_int  = np.repeat(labels_test_int[:,np.newaxis], n_bands, 1)

oh_enc = OneHotEncoder(sparse=False)
labels_train_ohe = oh_enc.fit_transform(labels_train_int)
labels_valid_ohe = oh_enc.fit_transform(labels_valid_int)
labels_train_ohe = oh_enc.fit_transform(labels_test_int)

# uniques, labels_valid = np.unique(labels_valid, return_inverse=True)
labels_train_cat = np_utils.to_categorical(labels_train_int)
labels_valid_cat = np_utils.to_categorical(labels_valid_int)
labels_test_cat  = np_utils.to_categorical(labels_test_int)

#n_classes = labels_valid_ohe.shape[1]
n_classes = 15
# must hard-code this one

print("Labels formats for convolutional layers:")

print("Train      int label format (?, ?, n_samples, n_channels)         | ", labels_train_int.shape)
print("Validation int label format (?, ?, n_samples, n_channels)         | ", labels_valid_int.shape)
print("Test       int label format (?, ?, n_samples, n_channels)         | ", labels_test_int.shape)
# Out:
# Labels formats for convolutional layers:
# Train      int label format (?, ?, n_samples, n_channels)         |  (4418, 1)
# Validation int label format (?, ?, n_samples, n_channels)         |  (552, 1)
# Test       int label format (?, ?, n_samples, n_channels)         |  (553, 1)

# %%
n_pixels = data_train.shape[1] 

# Formatting data for convolutional layer:
n_train_targets = data_train.shape[0]
n_valid_targets = data_valid.shape[0]
n_test_targets  = data_test.shape[0]

#labels_train_int_4D = np.expand_dims(labels_train_int   , axis=0)
#labels_train_int_4D = np.expand_dims(labels_train_int_4D, axis=0)
#labels_valid_int_4D = np.expand_dims(labels_valid_int   , axis=0)
#labels_valid_int_4D = np.expand_dims(labels_valid_int_4D, axis=0)
#labels_test_int_4D  = np.expand_dims(labels_test_int    , axis=0)
#labels_test_int_4D  = np.expand_dims(labels_test_int_4D , axis=0)


print("Data formats for convolutional layers:")

print("Train      4D data format (n_samples,size_x, size_y, n_channels) | ", data_train.shape)
print("Validation 4D data format (n_samples,size_x, size_y, n_channels) | ", data_valid.shape)
print("Test       4D data format (n_samples,size_x, size_y, n_channels) | ", data_test.shape)

#print("Train      4D label format (?, ?, n_samples, n_channels)         | ", labels_train_int_4D.shape)
#print("Validation 4D label format (?, ?, n_samples, n_channels)         | ", labels_valid_int_4D.shape)
#print("Test       4D label format (?, ?, n_samples, n_channels)         | ", labels_test_int_4D.shape)
# Out:
# Data formats for convolutional layers:
# Train      4D data format (n_samples,size_x, size_y, n_channels) |  (4418, 32, 32, 6)
# Validation 4D data format (n_samples,size_x, size_y, n_channels) |  (552, 32, 32, 6)
# Test       4D data format (n_samples,size_x, size_y, n_channels) |  (553, 32, 32, 6)

# %%
# Trying with less bands:

n_bands = 6

data_train = data_train[:,:,:,:n_bands]
data_valid = data_valid[:,:,:,:n_bands]
data_test  = data_test [:,:,:,:n_bands]

if (n_bands == 1):
    data_train = np.expand_dims(data_train, axis=3)
    data_valid = np.expand_dims(data_valid, axis=3)
    data_test  = np.expand_dims(data_test, axis=3)


print("Data formats for convolutional layers - 1 band:")

print("Train      4D data format (n_samples,size_x, size_y, n_channels) | ", data_train.shape)
print("Validation 4D data format (n_samples,size_x, size_y, n_channels) | ", data_valid.shape)
print("Test       4D data format (n_samples,size_x, size_y, n_channels) | ", data_test.shape)
# Out:
# Data formats for convolutional layers - 1 band:
# Train      4D data format (n_samples,size_x, size_y, n_channels) |  (4418, 32, 32, 6)
# Validation 4D data format (n_samples,size_x, size_y, n_channels) |  (552, 32, 32, 6)
# Test       4D data format (n_samples,size_x, size_y, n_channels) |  (553, 32, 32, 6)

# %% [markdown]
# ### Convolutional 2D layers
#
# Not working with 'mean_squared_error' loss
#
# Loss function gets stuck when using 'softmax' activation

# %%
# Best for SDSS:
#
#model_Conv = keras.Sequential([
#                          keras.layers.Conv2D(8, kernel_size=(4,4), strides=(2,2), padding='same',
#                                              activation=tf.nn.relu, input_shape=(n_pixels,n_pixels,1)),
#                          keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
#                          keras.layers.Conv2D(64, kernel_size=(2,2), strides=(1,1), padding='same',
#                                              activation=tf.nn.relu),
#                          keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
#                          keras.layers.Conv2D(128, kernel_size=(2,2), strides=(1,1), padding='same',
#                                              activation=tf.nn.relu),
#                          keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
#                          #keras.layers.Dropout(0.3),
#                          keras.layers.Flatten(),
#                          keras.layers.Dense(10, activation=tf.nn.sigmoid),
#                          keras.layers.Dropout(0.3),
#                          keras.layers.Dense(n_classes, activation=tf.nn.sigmoid)
#                          ])

model_Conv = keras.Sequential([
                          keras.layers.Conv2D(8, kernel_size=(4,4), strides=(2,2), padding='same',
                                              activation=tf.nn.relu, input_shape=(n_pixels,n_pixels,n_bands),
                                              data_format="channels_last"),
#                          keras.layers.Dropout(0.2),
#                          keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
                          keras.layers.Conv2D(16, kernel_size=(4,4), strides=(2,2), padding='same',
                                              activation=tf.nn.relu),
                          keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
                          keras.layers.Conv2D(32, kernel_size=(2,2), strides=(1,1), padding='same',
                                              activation=tf.nn.relu),
                          #keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
#                          keras.layers.Dropout(0.2),
                          keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
                          keras.layers.Flatten(),
                          keras.layers.Dense(128, activation=tf.nn.sigmoid),
                          keras.layers.Dropout(0.3),
                          keras.layers.Dense(9, activation=tf.nn.sigmoid)   # < CHANGE number of classes here!
                          ])

model_Conv.compile(optimizer=tf.train.AdamOptimizer(learning_rate=0.001), 
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

model_Conv.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 16, 16, 8)         776
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 16)          2064
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 32)          2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 22,593
# Trainable params: 22,593
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_Conv = model_Conv.fit(data_train, labels_train_int, validation_data=(data_valid, labels_valid_int),
                    epochs=50, batch_size=256, verbose=2)
# Out:
# Train on 4418 samples, validate on 552 samples
# Epoch 1/50
#  - 1s - loss: 1.9469 - acc: 0.3746 - val_loss: 1.7916 - val_acc: 0.4167
# Epoch 2/50
#  - 1s - loss: 1.7774 - acc: 0.4117 - val_loss: 1.7661 - val_acc: 0.4167
# Epoch 3/50
#  - 1s - loss: 1.7633 - acc: 0.4194 - val_loss: 1.7471 - val_acc: 0.4167
# Epoch 4/50
#  - 1s - loss: 1.7526 - acc: 0.4206 - val_loss: 1.7322 - val_acc: 0.4167
# Epoch 5/50
#  - 1s - loss: 1.7357 - acc: 0.4206 - val_loss: 1.7258 - val_acc: 0.4167
# Epoch 6/50
#  - 1s - loss: 1.7225 - acc: 0.4206 - val_loss: 1.7210 - val_acc: 0.4167
# Epoch 7/50
#  - 1s - loss: 1.7193 - acc: 0.4206 - val_loss: 1.7098 - val_acc: 0.4167
# Epoch 8/50
#  - 1s - loss: 1.7104 - acc: 0.4206 - val_loss: 1.7025 - val_acc: 0.4167
# Epoch 9/50
#  - 1s - loss: 1.6930 - acc: 0.4206 - val_loss: 1.6913 - val_acc: 0.4167
# Epoch 10/50
#  - 1s - loss: 1.6802 - acc: 0.4206 - val_loss: 1.6856 - val_acc: 0.4167
# Epoch 11/50
#  - 1s - loss: 1.6669 - acc: 0.4206 - val_loss: 1.6750 - val_acc: 0.4167
# Epoch 12/50
#  - 1s - loss: 1.6578 - acc: 0.4206 - val_loss: 1.6645 - val_acc: 0.4167
# Epoch 13/50
#  - 1s - loss: 1.6484 - acc: 0.4206 - val_loss: 1.6628 - val_acc: 0.4167
# Epoch 14/50
#  - 1s - loss: 1.6461 - acc: 0.4208 - val_loss: 1.6583 - val_acc: 0.4167
# Epoch 15/50
#  - 1s - loss: 1.6350 - acc: 0.4206 - val_loss: 1.6484 - val_acc: 0.4167
# Epoch 16/50
#  - 1s - loss: 1.6252 - acc: 0.4208 - val_loss: 1.6404 - val_acc: 0.4167
# Epoch 17/50
#  - 1s - loss: 1.6193 - acc: 0.4199 - val_loss: 1.6276 - val_acc: 0.4167
# Epoch 18/50
#  - 1s - loss: 1.6100 - acc: 0.4215 - val_loss: 1.6237 - val_acc: 0.4167
# Epoch 19/50
#  - 1s - loss: 1.6089 - acc: 0.4235 - val_loss: 1.6204 - val_acc: 0.4167
# Epoch 20/50
#  - 1s - loss: 1.5966 - acc: 0.4230 - val_loss: 1.6163 - val_acc: 0.4167
# Epoch 21/50
#  - 1s - loss: 1.5916 - acc: 0.4226 - val_loss: 1.6096 - val_acc: 0.4239
# Epoch 22/50
#  - 1s - loss: 1.5788 - acc: 0.4221 - val_loss: 1.6038 - val_acc: 0.4167
# Epoch 23/50
#  - 1s - loss: 1.5734 - acc: 0.4271 - val_loss: 1.5954 - val_acc: 0.4185
# Epoch 24/50
#  - 1s - loss: 1.5639 - acc: 0.4325 - val_loss: 1.5900 - val_acc: 0.4330
# Epoch 25/50
#  - 1s - loss: 1.5577 - acc: 0.4307 - val_loss: 1.5842 - val_acc: 0.4384
# Epoch 26/50
#  - 1s - loss: 1.5549 - acc: 0.4425 - val_loss: 1.5790 - val_acc: 0.4366
# Epoch 27/50
#  - 1s - loss: 1.5511 - acc: 0.4430 - val_loss: 1.5760 - val_acc: 0.4366
# Epoch 28/50
#  - 1s - loss: 1.5432 - acc: 0.4400 - val_loss: 1.5736 - val_acc: 0.4384
# Epoch 29/50
#  - 1s - loss: 1.5223 - acc: 0.4502 - val_loss: 1.5616 - val_acc: 0.4348
# Epoch 30/50
#  - 1s - loss: 1.5211 - acc: 0.4559 - val_loss: 1.5668 - val_acc: 0.4384
# Epoch 31/50
#  - 1s - loss: 1.5077 - acc: 0.4588 - val_loss: 1.5559 - val_acc: 0.4366
# Epoch 32/50
#  - 1s - loss: 1.5001 - acc: 0.4645 - val_loss: 1.5466 - val_acc: 0.4384
# Epoch 33/50
#  - 1s - loss: 1.4864 - acc: 0.4670 - val_loss: 1.5393 - val_acc: 0.4348
# Epoch 34/50
#  - 1s - loss: 1.4852 - acc: 0.4688 - val_loss: 1.5336 - val_acc: 0.4402
# Epoch 35/50
#  - 1s - loss: 1.4713 - acc: 0.4740 - val_loss: 1.5329 - val_acc: 0.4438
# Epoch 36/50
#  - 1s - loss: 1.4626 - acc: 0.4844 - val_loss: 1.5219 - val_acc: 0.4475
# Epoch 37/50
#  - 1s - loss: 1.4584 - acc: 0.4837 - val_loss: 1.5281 - val_acc: 0.4366
# Epoch 38/50
#  - 1s - loss: 1.4463 - acc: 0.4826 - val_loss: 1.5170 - val_acc: 0.4565
# Epoch 39/50
#  - 1s - loss: 1.4284 - acc: 0.4894 - val_loss: 1.5192 - val_acc: 0.4511
# Epoch 40/50
#  - 1s - loss: 1.4317 - acc: 0.4934 - val_loss: 1.5358 - val_acc: 0.4475
# Epoch 41/50
#  - 1s - loss: 1.4304 - acc: 0.4862 - val_loss: 1.5212 - val_acc: 0.4547
# Epoch 42/50
#  - 1s - loss: 1.4219 - acc: 0.4907 - val_loss: 1.5158 - val_acc: 0.4547
# Epoch 43/50
#  - 1s - loss: 1.4153 - acc: 0.4930 - val_loss: 1.5182 - val_acc: 0.4475
# Epoch 44/50
#  - 1s - loss: 1.4055 - acc: 0.5020 - val_loss: 1.5378 - val_acc: 0.4112
# Epoch 45/50
#  - 1s - loss: 1.4008 - acc: 0.4950 - val_loss: 1.5053 - val_acc: 0.4583
# Epoch 46/50
#  - 1s - loss: 1.3881 - acc: 0.5070 - val_loss: 1.5025 - val_acc: 0.4565
# Epoch 47/50
#  - 1s - loss: 1.3802 - acc: 0.5048 - val_loss: 1.5207 - val_acc: 0.4420
# Epoch 48/50
#  - 1s - loss: 1.3861 - acc: 0.5036 - val_loss: 1.5207 - val_acc: 0.4493
# Epoch 49/50
#  - 1s - loss: 1.3697 - acc: 0.5025 - val_loss: 1.5111 - val_acc: 0.4529
# Epoch 50/50
#  - 1s - loss: 1.3617 - acc: 0.5118 - val_loss: 1.5082 - val_acc: 0.4547

# %%
# > Model evolution:
plt.plot(history_Conv.history['loss'])
plt.plot(history_Conv.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()


print('Number of different classes in train sample: ' + str(len(np.unique(labels_train))))
print('Number of different classes in valid sample: ' + str(len(np.unique(labels_valid))))
print('Number of different classes in test  sample: ' + str(len(np.unique(labels_test))))
print('')
print('WARNING: A disply error can occur if the represented classes differ in the train/valid/test sets.')
print('         If so, increase the samples.')


# > Comparison with predictions:
labels_pred_float_Conv = model_Conv.predict(data_test)

labels_pred_Conv = int_enc.inverse_transform(labels_pred_float_Conv.argmax(1))
# reversing one hot encoding


print("Classification report for %s:\n%s\n"
      % (model_Conv, metrics.classification_report(labels_test, labels_pred_Conv)))
print("Confusion matrix:\n%s" % metrics.confusion_matrix(labels_test, labels_pred_Conv))


# > Plotting a few misclassified images (wrong labels):

print('Examples of misclassified images:')

# equivalent(?): indexes_wrong = np.nonzero(labels_pred_Conv != labels_test_int)
indexes_wrong = [labels_pred_Conv != labels_test]
# indexes of misclassified objects <indexed within range(data_test) or range(labels_pred_*)>

labels_pred_int_Conv = labels_pred_float_Conv.argmax(1)

data_test_wrong            = data_test[indexes_wrong]
labels_test_int_wrong      = labels_test_int[indexes_wrong]
labels_pred_int_Conv_wrong = labels_pred_int_Conv[indexes_wrong]

fig = plt.figure(figsize=(15,10))
plt.subplots_adjust(hspace=0.25,wspace=0.05)

       
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.axis('off')
    image_wrong = (data_test_wrong[i,:,:,0].reshape(n_pixels,n_pixels))
    # using only first band in array
    
    vmin,vmax = np.percentile(image_wrong.flatten(),[1,99])
    # min and max are set as percentiles for each image

    plt.imshow(image_wrong, vmin=vmin, vmax=vmax, interpolation='nearest')
    plt.title('label = %s | pred = %s' % (labels_unique[labels_test_int_wrong[i][0]] , labels_unique[labels_pred_int_Conv_wrong[i]]))
# Out:
# Number of different classes in train sample: 9
# Number of different classes in valid sample: 9
# Number of different classes in test  sample: 9
#
# WARNING: A disply error can occur if the represented classes differ in the train/valid/test sets.
#          If so, increase the samples.
# Classification report for <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fe7d409c3c8>:
#               precision    recall  f1-score   support
#
#           15       0.43      0.27      0.33        48
#           42       0.26      0.13      0.17       119
#           52       0.00      0.00      0.00        18
#           62       0.00      0.00      0.00        41
#           64       0.00      0.00      0.00        15
#           67       0.00      0.00      0.00        20
#           88       0.75      0.60      0.67        45
#           90       0.47      0.89      0.62       225
#           95       0.50      0.09      0.15        22
#
#    micro avg       0.46      0.46      0.46       553
#    macro avg       0.27      0.22      0.22       553
# weighted avg       0.37      0.46      0.38       553
#
#
# Confusion matrix:
# [[ 13   5   0   0   0   0   2  27   1]
#  [  3  15   0   0   0   0   2  98   1]
#  [  2   3   0   0   0   0   0  13   0]
#  [  1   8   0   0   0   0   2  30   0]
#  [  0   0   0   0   0   0   0  15   0]
#  [  1   1   0   0   0   0   0  18   0]
#  [  0   2   0   0   0   0  27  16   0]
#  [  7  16   0   0   0   0   2 200   0]
#  [  3   8   0   0   0   0   1   8   2]]
# Examples of misclassified images:

# %% [markdown]
# https://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/
#
# ## Using Tensorflow
# https://github.com/aymericdamien/TensorFlow-Examples/blob/master/notebooks/3_NeuralNetworks/neural_network_raw.ipynb
#
# https://github.com/aymericdamien/TensorFlow-Examples/blob/master/notebooks/3_NeuralNetworks/neural_network.ipynb

# %% [markdown]
# ## Final check
# Using the test sample for a final check of the various algorithms used above.
#
# Checking if their performance is as good as it is reported in the validation process.

# %%
#print("====================================================================================")
# Predictions for SVM:
#predicted = model_svc.predict(data_test)
#print("Classification report for %s:\n%s\n"
#      % (model_svc, metrics.classification_report(labels_test, predicted)))
#print("Confusion matrix:\n%s \n" % metrics.confusion_matrix(labels_test, predicted))
#print("====================================================================================")

# Predictions for LogisticRegression:
#predicted = model_svc.predict(data_test)
#print("Classification report for %s:\n%s\n"
#      % (model_lrc, metrics.classification_report(labels_test, predicted)))
#print("Confusion matrix:\n%s \n" % metrics.confusion_matrix(labels_test, predicted))
#print("====================================================================================")

# Predictions for MLP:
#predicted = model_MLP.predict(data_test)
#print("Classification report for %s:\n%s\n"
#      % (model_MLP, metrics.classification_report(labels_test, predicted)))
#print("Confusion matrix:\n%s \n" % metrics.confusion_matrix(labels_test, predicted))
#print("====================================================================================")

# Predictions for RandomForests:
#predicted = model_RF.predict(data_test)
#print("Classification report for %s:\n%s\n"
#      % (model_RF, metrics.classification_report(labels_test, predicted)))
#print("Confusion matrix:\n%s \n" % metrics.confusion_matrix(labels_test, predicted))
#print("====================================================================================")

# Predictions for Keras 1D Neural Network:
#labels_pred_float_1D = model_1D.predict(data_test)
#labels_pred_1D = int_enc.inverse_transform(labels_pred_float_1D.argmax(1))
#print("Classification report for %s:\n%s\n"
#      % (model_1D, metrics.classification_report(labels_test, labels_pred_1D)))
#print("Confusion matrix:\n%s" % metrics.confusion_matrix(labels_test, labels_pred_1D))
#print("====================================================================================")

# Predictions for Keras Convolutional Neural Network:
labels_pred_float_Conv = model_Conv.predict(data_test)
labels_pred_Conv = int_enc.inverse_transform(labels_pred_float_Conv.argmax(1))
print("Classification report for %s:\n%s\n"
      % (model_Conv, metrics.classification_report(labels_test, labels_pred_Conv)))
print("Confusion matrix:\n%s" % metrics.confusion_matrix(labels_test, labels_pred_Conv))
print("====================================================================================")
# Out:
# Classification report for <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fe7d409c3c8>:
#               precision    recall  f1-score   support
#
#           15       0.43      0.27      0.33        48
#           42       0.26      0.13      0.17       119
#           52       0.00      0.00      0.00        18
#           62       0.00      0.00      0.00        41
#           64       0.00      0.00      0.00        15
#           67       0.00      0.00      0.00        20
#           88       0.75      0.60      0.67        45
#           90       0.47      0.89      0.62       225
#           95       0.50      0.09      0.15        22
#
#    micro avg       0.46      0.46      0.46       553
#    macro avg       0.27      0.22      0.22       553
# weighted avg       0.37      0.46      0.38       553
#
#
# Confusion matrix:
# [[ 13   5   0   0   0   0   2  27   1]
#  [  3  15   0   0   0   0   2  98   1]
#  [  2   3   0   0   0   0   0  13   0]
#  [  1   8   0   0   0   0   2  30   0]
#  [  0   0   0   0   0   0   0  15   0]
#  [  1   1   0   0   0   0   0  18   0]
#  [  0   2   0   0   0   0  27  16   0]
#  [  7  16   0   0   0   0   2 200   0]
#  [  3   8   0   0   0   0   1   8   2]]
# ====================================================================================

# %% [markdown]
# # Saving the trained models
# Using pickle we can save the trained models to use them in a later time w/o the need to re-train them.

# %%
#import pickle
#import os

## saving the models to disk
#folder_saved = "saved_models/v2.1"

#model_labels = ['SVC','LogReg','MLP','RandFor','Ker_1D','Ker_Conv']
#models = ['model_SVC','model_LR','model_MLP','model_RF','model_1D','model_Conv']

#if not os.path.exists(folder_saved):
#    os.makedirs(folder_saved)
    
#for modstr,model in zip(model_labels,models):
#    pickle.dump(model, open(folder_saved+'/galaxy_classification_SDSS_v1_'+modstr+'.sav', 'wb'))


# To load the models at a later time:
# loaded_model = pickle.load(open(filename, 'rb'))
# result = loaded_model.score(X_test, Y_test)
# print(result)
